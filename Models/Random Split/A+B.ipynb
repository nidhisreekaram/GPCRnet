# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.nn import GINConv, global_mean_pool
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix,
    ConfusionMatrixDisplay, precision_score,
    recall_score, f1_score
)
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np
import random

# Reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)

# === Load Dataset ===
def load_pytorch_dataset(file_path):
    with open(file_path, 'rb') as f:
        dataset = pickle.load(f)
    print(f"✅ Dataset successfully loaded from {file_path}")
    return dataset

pickle_file_path = r"C:\Users\nidhi\Downloads\Pickle files\Random Split\One-Hot\GPCR_A+B.pkl"
pytorch_dataset = load_pytorch_dataset(pickle_file_path)

# === Model ===
class SimpleGINModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate):
        super(SimpleGINModel, self).__init__()
        self.gin1 = GINConv(nn.Linear(input_dim, hidden_dim))
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.gin2 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.gin3 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn3 = nn.BatchNorm1d(hidden_dim)
        self.gin4 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn4 = nn.BatchNorm1d(hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.bn1(self.gin1(x, edge_index)))
        x = F.relu(self.bn2(self.gin2(x, edge_index)))
        x = F.relu(self.bn3(self.gin3(x, edge_index)))
        x = F.relu(self.bn4(self.gin4(x, edge_index)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return self.fc(x)

# === Training ===
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct = 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        data.y = data.y.long()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        correct += (out.argmax(dim=1) == data.y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# === Evaluation ===
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss, correct = 0, 0
    all_labels, all_preds, all_probs = [], [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            data.y = data.y.long()
            out = model(data)
            loss = criterion(out, data.y)
            total_loss += loss.item() * data.num_graphs
            correct += (out.argmax(dim=1) == data.y).sum().item()
            probs = F.softmax(out, dim=1)[:, 1].cpu().numpy()
            all_labels.extend(data.y.cpu().numpy())
            all_preds.extend(out.argmax(dim=1).cpu().numpy())
            all_probs.extend(probs)
    return total_loss / len(loader.dataset), correct / len(loader.dataset), \
           np.array(all_labels), np.array(all_preds), np.array(all_probs)

# === Plot Training Metrics (Clean Style) ===
def plot_metrics(epochs, train_loss, train_acc, test_loss, test_acc, model_type):
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_loss, color="red")
    plt.plot(epochs, test_loss, color="orange")
    plt.plot(epochs, train_acc, color="green")
    plt.plot(epochs, test_acc, color="blue")
    plt.xticks([])
    plt.yticks([])
    plt.title(f"{model_type} Metrics", fontsize=14)
    plt.tight_layout()
    plt.savefig(f"{model_type}_metrics_plot.png", bbox_inches='tight')
    plt.close()
    print(f"🖼️ Metrics plot saved as {model_type}_metrics_plot.png")

# === Prepare Data ===
train_data, test_data = train_test_split(pytorch_dataset, test_size=0.2, random_state=seed)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# === Initialize Model ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleGINModel(20, 64, 2, 0.5).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# === Training Loop ===
num_epochs = 350
train_losses, train_accs, test_losses, test_accs = [], [], [], []
history = []

for epoch in range(1, num_epochs + 1):
    tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
    te_loss, te_acc, y_true, y_pred, y_probs = evaluate(model, test_loader, criterion, device)

    train_losses.append(tr_loss)
    train_accs.append(tr_acc)
    test_losses.append(te_loss)
    test_accs.append(te_acc)
    history.append((y_true, y_pred, y_probs))

    print(f"Epoch {epoch:03d}: Train Loss={tr_loss:.4f}, Train Acc={tr_acc:.4f}, Test Loss={te_loss:.4f}, Test Acc={te_acc:.4f}")

# === Plot ===
plot_metrics(range(1, num_epochs + 1),
             train_losses, train_accs,
             test_losses, test_accs,
             "A+B_OneHot_64_NoWD"
)

# === Save to Excel ===
df_metrics = pd.DataFrame({
    "Epoch": list(range(1, num_epochs + 1)),
    "Train Accuracy": [round(acc * 100, 2) for acc in train_accs],
    "Train Loss": [round(loss, 2) for loss in train_losses],
    "Test Accuracy": [round(acc * 100, 2) for acc in test_accs],
    "Test Loss": [round(loss, 2) for loss in test_losses],
})

df_metrics.to_excel("A+B_OneHot_64_NoWD.xlsx", index=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.nn import GINConv, global_mean_pool
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    precision_score, recall_score, f1_score
)
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np
import random
import os

# === Reproducibility ===
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)

# === Load Dataset ===
def load_pytorch_dataset(file_path):
    with open(file_path, 'rb') as f:
        dataset = pickle.load(f)
    print(f"✅ Dataset loaded from {file_path}")
    return dataset

pickle_file_path = r"C:\Users\nidhi\Downloads\IICT\Pickle files\Random Split\One-Hot\GPCR_A+B.pkl"
pytorch_dataset = load_pytorch_dataset(pickle_file_path)

# === Add ID for tracking ===
for i, data in enumerate(pytorch_dataset):
    data.id = i

# === Model ===
class SimpleGINModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate):
        super(SimpleGINModel, self).__init__()
        self.gin1 = GINConv(nn.Linear(input_dim, hidden_dim))
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.gin2 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.gin3 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn3 = nn.BatchNorm1d(hidden_dim)
        self.gin4 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn4 = nn.BatchNorm1d(hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.bn1(self.gin1(x, edge_index)))
        x = F.relu(self.bn2(self.gin2(x, edge_index)))
        x = F.relu(self.bn3(self.gin3(x, edge_index)))
        x = F.relu(self.bn4(self.gin4(x, edge_index)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return self.fc(x)

# === Training ===
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct = 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        data.y = data.y.long()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        correct += (out.argmax(dim=1) == data.y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# === Evaluation (with ID tracking) ===
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss, correct = 0, 0
    all_labels, all_preds, all_probs, all_ids = [], [], [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            data.y = data.y.long()
            out = model(data)
            loss = criterion(out, data.y)
            total_loss += loss.item() * data.num_graphs
            preds = out.argmax(dim=1)
            correct += (preds == data.y).sum().item()
            all_labels.extend(data.y.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(F.softmax(out, dim=1)[:, 1].cpu().numpy())
            all_ids.extend(data.id.cpu().numpy())
    return total_loss / len(loader.dataset), correct / len(loader.dataset), \
           np.array(all_labels), np.array(all_preds), np.array(all_probs), np.array(all_ids)

# === Plot Metrics ===
def plot_metrics(epochs, train_loss, train_acc, test_loss, test_acc, model_type):
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_loss, color="red")
    plt.plot(epochs, test_loss, color="orange")
    plt.plot(epochs, train_acc, color="green")
    plt.plot(epochs, test_acc, color="blue")
    plt.xticks([])
    plt.yticks([])
    plt.title(f"{model_type} Metrics", fontsize=14)
    plt.tight_layout()
    plt.savefig(f"{model_type}_metrics_plot.png", bbox_inches='tight')
    plt.close()
    print(f"🖼️ Metrics plot saved as {model_type}_metrics_plot.png")

# === Prepare Data ===
train_data, test_data = train_test_split(pytorch_dataset, test_size=0.2, random_state=seed)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# === Initialize Model ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleGINModel(20, 64, 2, 0.5).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# === Training Loop ===
num_epochs = 400
train_losses, train_accs, test_losses, test_accs = [], [], [], []

# Store best accuracy and its epoch
best_test_acc = 0
best_epoch_data = {}

for epoch in range(1, num_epochs + 1):
    tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
    te_loss, te_acc, y_true, y_pred, y_probs, y_ids = evaluate(model, test_loader, criterion, device)

    train_losses.append(tr_loss)
    train_accs.append(tr_acc)
    test_losses.append(te_loss)
    test_accs.append(te_acc)

    print(f"Epoch {epoch:03d}: Train Loss={tr_loss:.4f}, Train Acc={tr_acc:.4f}, Test Loss={te_loss:.4f}, Test Acc={te_acc:.4f}")

    if te_acc > best_test_acc:
        best_test_acc = te_acc
        best_epoch_data = {
            "epoch": epoch,
            "y_true": y_true,
            "y_pred": y_pred,
            "y_ids": y_ids
        }

# === Best Epoch Results ===
best_epoch = best_epoch_data["epoch"]
y_true = best_epoch_data["y_true"]
y_pred = best_epoch_data["y_pred"]
y_ids = best_epoch_data["y_ids"]

# === Confusion Matrix and Indices ===
conf_matrix = confusion_matrix(y_true, y_pred)
print(f"\n📊 Confusion Matrix at Highest Accuracy (Epoch {best_epoch}):")
print(conf_matrix)

tp_ids = y_ids[(y_true == 1) & (y_pred == 1)]
fp_ids = y_ids[(y_true == 0) & (y_pred == 1)]
tn_ids = y_ids[(y_true == 0) & (y_pred == 0)]
fn_ids = y_ids[(y_true == 1) & (y_pred == 0)]

print(f"\n📌 TP/FP/TN/FN Indices at Epoch {best_epoch}:")
print(f"✅ TP: {tp_ids.tolist()}")
print(f"❌ FP: {fp_ids.tolist()}")
print(f"✅ TN: {tn_ids.tolist()}")
print(f"❌ FN: {fn_ids.tolist()}")

# === Save Indices ===
with open(f"TP_FP_TN_FN_Epoch_{best_epoch}.pkl", "wb") as f:
    pickle.dump({
        "TP": tp_ids.tolist(),
        "FP": fp_ids.tolist(),
        "TN": tn_ids.tolist(),
        "FN": fn_ids.tolist()
    }, f)
print(f"💾 Indices saved to: TP_FP_TN_FN_Epoch_{best_epoch}.pkl")

# === Save Confusion Matrix Plot ===
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Class 0", "Class 1"])
disp.plot(cmap='Blues', values_format='d')
plt.title(f"Confusion Matrix (Epoch {best_epoch})")
plt.tight_layout()
plt.savefig(f"Confusion_Matrix_Epoch_{best_epoch}.png")
plt.show()
print(f"🖼️ Confusion matrix saved as Confusion_Matrix_Epoch_{best_epoch}.png")

# === Plot Final Metrics ===
plot_metrics(range(1, num_epochs + 1),
             train_losses, train_accs,
             test_losses, test_accs,
             "A+B_OneHot_64_NoWD")

# === Save Epoch-wise Metrics to Excel ===
df_metrics = pd.DataFrame({
    "Epoch": list(range(1, num_epochs + 1)),
    "Train Accuracy": [round(acc * 100, 2) for acc in train_accs],
    "Train Loss": [round(loss, 2) for loss in train_losses],
    "Test Accuracy": [round(acc * 100, 2) for acc in test_accs],
    "Test Loss": [round(loss, 2) for loss in test_losses],
})
df_metrics.to_excel("A+B_OneHot_64_NoWD.xlsx", index=False)
print("📊 Metrics saved to A+B_OneHot_64_NoWD.xlsx")
# Out:
# ✅ Dataset loaded from C:\Users\nidhi\Downloads\IICT\Pickle files\Random Split\One-Hot\GPCR_A+B.pkl
# Epoch 001: Train Loss=0.6920, Train Acc=0.5453, Test Loss=0.6620, Test Acc=0.6786
# Epoch 002: Train Loss=0.6676, Train Acc=0.6692, Test Loss=0.6461, Test Acc=0.6786
# Epoch 003: Train Loss=0.6485, Train Acc=0.7407, Test Loss=0.6385, Test Acc=0.7296
# Epoch 004: Train Loss=0.6269, Train Acc=0.7586, Test Loss=0.6256, Test Acc=0.7500
# Epoch 005: Train Loss=0.6100, Train Acc=0.7586, Test Loss=0.6095, Test Acc=0.7602
# Epoch 006: Train Loss=0.5942, Train Acc=0.7625, Test Loss=0.5947, Test Acc=0.7602
# Epoch 007: Train Loss=0.5802, Train Acc=0.7561, Test Loss=0.5798, Test Acc=0.7602
# Epoch 008: Train Loss=0.5668, Train Acc=0.7612, Test Loss=0.5678, Test Acc=0.7653
# Epoch 009: Train Loss=0.5543, Train Acc=0.7663, Test Loss=0.5562, Test Acc=0.7653
# Epoch 010: Train Loss=0.5442, Train Acc=0.7714, Test Loss=0.5451, Test Acc=0.7653
# Epoch 011: Train Loss=0.5336, Train Acc=0.7688, Test Loss=0.5362, Test Acc=0.7755
# Epoch 012: Train Loss=0.5243, Train Acc=0.7778, Test Loss=0.5273, Test Acc=0.7857
# Epoch 013: Train Loss=0.5138, Train Acc=0.7791, Test Loss=0.5183, Test Acc=0.7857
# Epoch 014: Train Loss=0.5063, Train Acc=0.7803, Test Loss=0.5123, Test Acc=0.7857
# Epoch 015: Train Loss=0.4985, Train Acc=0.7803, Test Loss=0.5055, Test Acc=0.7857
# Epoch 016: Train Loss=0.4912, Train Acc=0.7778, Test Loss=0.4990, Test Acc=0.7857
# Epoch 017: Train Loss=0.4873, Train Acc=0.7842, Test Loss=0.4930, Test Acc=0.7857
# Epoch 018: Train Loss=0.4818, Train Acc=0.7829, Test Loss=0.4893, Test Acc=0.7857
# Epoch 019: Train Loss=0.4724, Train Acc=0.7880, Test Loss=0.4837, Test Acc=0.7857
# Epoch 020: Train Loss=0.4682, Train Acc=0.7880, Test Loss=0.4773, Test Acc=0.7959
# Epoch 021: Train Loss=0.4608, Train Acc=0.7931, Test Loss=0.4730, Test Acc=0.8061
# Epoch 022: Train Loss=0.4561, Train Acc=0.7893, Test Loss=0.4690, Test Acc=0.8010
# Epoch 023: Train Loss=0.4503, Train Acc=0.7957, Test Loss=0.4641, Test Acc=0.8010
# Epoch 024: Train Loss=0.4469, Train Acc=0.7982, Test Loss=0.4588, Test Acc=0.8316
# Epoch 025: Train Loss=0.4397, Train Acc=0.8072, Test Loss=0.4549, Test Acc=0.8418
# Epoch 026: Train Loss=0.4314, Train Acc=0.8084, Test Loss=0.4524, Test Acc=0.8418
# Epoch 027: Train Loss=0.4286, Train Acc=0.8072, Test Loss=0.4482, Test Acc=0.8367
# Epoch 028: Train Loss=0.4254, Train Acc=0.8135, Test Loss=0.4444, Test Acc=0.8367
# Epoch 029: Train Loss=0.4220, Train Acc=0.8148, Test Loss=0.4404, Test Acc=0.8367
# Epoch 030: Train Loss=0.4169, Train Acc=0.8161, Test Loss=0.4355, Test Acc=0.8316
# Epoch 031: Train Loss=0.4112, Train Acc=0.8135, Test Loss=0.4330, Test Acc=0.8316
# Epoch 032: Train Loss=0.4083, Train Acc=0.8327, Test Loss=0.4328, Test Acc=0.8418
# Epoch 033: Train Loss=0.4012, Train Acc=0.8429, Test Loss=0.4294, Test Acc=0.8367
# Epoch 034: Train Loss=0.4010, Train Acc=0.8365, Test Loss=0.4286, Test Acc=0.8418
# Epoch 035: Train Loss=0.3942, Train Acc=0.8442, Test Loss=0.4221, Test Acc=0.8469
# Epoch 036: Train Loss=0.3905, Train Acc=0.8467, Test Loss=0.4209, Test Acc=0.8469
# Epoch 037: Train Loss=0.3831, Train Acc=0.8467, Test Loss=0.4203, Test Acc=0.8571
# Epoch 038: Train Loss=0.3824, Train Acc=0.8467, Test Loss=0.4178, Test Acc=0.8469
# Epoch 039: Train Loss=0.3775, Train Acc=0.8531, Test Loss=0.4147, Test Acc=0.8520
# Epoch 040: Train Loss=0.3726, Train Acc=0.8467, Test Loss=0.4128, Test Acc=0.8520
# Epoch 041: Train Loss=0.3691, Train Acc=0.8531, Test Loss=0.4088, Test Acc=0.8520
# Epoch 042: Train Loss=0.3666, Train Acc=0.8493, Test Loss=0.4049, Test Acc=0.8520
# Epoch 043: Train Loss=0.3622, Train Acc=0.8506, Test Loss=0.4032, Test Acc=0.8571
# Epoch 044: Train Loss=0.3534, Train Acc=0.8608, Test Loss=0.4008, Test Acc=0.8520
# Epoch 045: Train Loss=0.3565, Train Acc=0.8608, Test Loss=0.3986, Test Acc=0.8622
# Epoch 046: Train Loss=0.3503, Train Acc=0.8608, Test Loss=0.3962, Test Acc=0.8571
# Epoch 047: Train Loss=0.3508, Train Acc=0.8608, Test Loss=0.3935, Test Acc=0.8571
# Epoch 048: Train Loss=0.3426, Train Acc=0.8685, Test Loss=0.3933, Test Acc=0.8571
# Epoch 049: Train Loss=0.3399, Train Acc=0.8621, Test Loss=0.3921, Test Acc=0.8622
# Epoch 050: Train Loss=0.3332, Train Acc=0.8685, Test Loss=0.3897, Test Acc=0.8622
# Epoch 051: Train Loss=0.3327, Train Acc=0.8621, Test Loss=0.3887, Test Acc=0.8622
# Epoch 052: Train Loss=0.3323, Train Acc=0.8723, Test Loss=0.3822, Test Acc=0.8571
# Epoch 053: Train Loss=0.3253, Train Acc=0.8710, Test Loss=0.3836, Test Acc=0.8622
# Epoch 054: Train Loss=0.3224, Train Acc=0.8787, Test Loss=0.3814, Test Acc=0.8622
# Epoch 055: Train Loss=0.3209, Train Acc=0.8736, Test Loss=0.3791, Test Acc=0.8724
# Epoch 056: Train Loss=0.3184, Train Acc=0.8787, Test Loss=0.3764, Test Acc=0.8673
# Epoch 057: Train Loss=0.3117, Train Acc=0.8787, Test Loss=0.3754, Test Acc=0.8622
# Epoch 058: Train Loss=0.3109, Train Acc=0.8812, Test Loss=0.3725, Test Acc=0.8673
# Epoch 059: Train Loss=0.3036, Train Acc=0.8838, Test Loss=0.3674, Test Acc=0.8622
# Epoch 060: Train Loss=0.3023, Train Acc=0.8902, Test Loss=0.3667, Test Acc=0.8571
# Epoch 061: Train Loss=0.2979, Train Acc=0.8787, Test Loss=0.3653, Test Acc=0.8571
# Epoch 062: Train Loss=0.2943, Train Acc=0.8940, Test Loss=0.3618, Test Acc=0.8571
# Epoch 063: Train Loss=0.2956, Train Acc=0.8978, Test Loss=0.3593, Test Acc=0.8622
# Epoch 064: Train Loss=0.2910, Train Acc=0.8953, Test Loss=0.3614, Test Acc=0.8571
# Epoch 065: Train Loss=0.2877, Train Acc=0.8940, Test Loss=0.3589, Test Acc=0.8622
# Epoch 066: Train Loss=0.2863, Train Acc=0.8991, Test Loss=0.3577, Test Acc=0.8724
# Epoch 067: Train Loss=0.2809, Train Acc=0.9017, Test Loss=0.3553, Test Acc=0.8724
# Epoch 068: Train Loss=0.2758, Train Acc=0.9055, Test Loss=0.3535, Test Acc=0.8673
# Epoch 069: Train Loss=0.2753, Train Acc=0.9029, Test Loss=0.3500, Test Acc=0.8724
# Epoch 070: Train Loss=0.2762, Train Acc=0.8991, Test Loss=0.3507, Test Acc=0.8776
# Epoch 071: Train Loss=0.2714, Train Acc=0.9004, Test Loss=0.3445, Test Acc=0.8724
# Epoch 072: Train Loss=0.2687, Train Acc=0.9017, Test Loss=0.3406, Test Acc=0.8878
# Epoch 073: Train Loss=0.2667, Train Acc=0.9055, Test Loss=0.3408, Test Acc=0.8776
# Epoch 074: Train Loss=0.2611, Train Acc=0.9093, Test Loss=0.3390, Test Acc=0.8724
# Epoch 075: Train Loss=0.2563, Train Acc=0.9093, Test Loss=0.3364, Test Acc=0.8776
# Epoch 076: Train Loss=0.2545, Train Acc=0.9068, Test Loss=0.3336, Test Acc=0.8827
# Epoch 077: Train Loss=0.2618, Train Acc=0.9106, Test Loss=0.3383, Test Acc=0.8724
# Epoch 078: Train Loss=0.2470, Train Acc=0.9132, Test Loss=0.3313, Test Acc=0.8776
# Epoch 079: Train Loss=0.2484, Train Acc=0.9144, Test Loss=0.3267, Test Acc=0.8878
# Epoch 080: Train Loss=0.2429, Train Acc=0.9183, Test Loss=0.3246, Test Acc=0.8827
# Epoch 081: Train Loss=0.2434, Train Acc=0.9157, Test Loss=0.3294, Test Acc=0.8827
# Epoch 082: Train Loss=0.2405, Train Acc=0.9208, Test Loss=0.3235, Test Acc=0.8878
# Epoch 083: Train Loss=0.2354, Train Acc=0.9208, Test Loss=0.3238, Test Acc=0.8980
# Epoch 084: Train Loss=0.2389, Train Acc=0.9221, Test Loss=0.3201, Test Acc=0.8980
# Epoch 085: Train Loss=0.2286, Train Acc=0.9246, Test Loss=0.3195, Test Acc=0.8980
# Epoch 086: Train Loss=0.2291, Train Acc=0.9183, Test Loss=0.3165, Test Acc=0.8878
# Epoch 087: Train Loss=0.2251, Train Acc=0.9246, Test Loss=0.3157, Test Acc=0.8980
# Epoch 088: Train Loss=0.2229, Train Acc=0.9298, Test Loss=0.3129, Test Acc=0.8980
# Epoch 089: Train Loss=0.2212, Train Acc=0.9259, Test Loss=0.3135, Test Acc=0.8878
# Epoch 090: Train Loss=0.2197, Train Acc=0.9336, Test Loss=0.3143, Test Acc=0.8929
# Epoch 091: Train Loss=0.2156, Train Acc=0.9323, Test Loss=0.3108, Test Acc=0.8980
# Epoch 092: Train Loss=0.2170, Train Acc=0.9310, Test Loss=0.3074, Test Acc=0.9082
# Epoch 093: Train Loss=0.2164, Train Acc=0.9234, Test Loss=0.3090, Test Acc=0.8980
# Epoch 094: Train Loss=0.2045, Train Acc=0.9336, Test Loss=0.3034, Test Acc=0.9082
# Epoch 095: Train Loss=0.2104, Train Acc=0.9272, Test Loss=0.3024, Test Acc=0.9031
# Epoch 096: Train Loss=0.2061, Train Acc=0.9374, Test Loss=0.3035, Test Acc=0.8929
# Epoch 097: Train Loss=0.2053, Train Acc=0.9336, Test Loss=0.3043, Test Acc=0.9184
# Epoch 098: Train Loss=0.2000, Train Acc=0.9349, Test Loss=0.2962, Test Acc=0.9082
# Epoch 099: Train Loss=0.2000, Train Acc=0.9349, Test Loss=0.2910, Test Acc=0.9082
# Epoch 100: Train Loss=0.1893, Train Acc=0.9413, Test Loss=0.2893, Test Acc=0.9082
# Epoch 101: Train Loss=0.1950, Train Acc=0.9400, Test Loss=0.2907, Test Acc=0.9082
# Epoch 102: Train Loss=0.1910, Train Acc=0.9413, Test Loss=0.2871, Test Acc=0.9133
# Epoch 103: Train Loss=0.1870, Train Acc=0.9387, Test Loss=0.2947, Test Acc=0.9082
# Epoch 104: Train Loss=0.1852, Train Acc=0.9464, Test Loss=0.2919, Test Acc=0.8980
# Epoch 105: Train Loss=0.1865, Train Acc=0.9374, Test Loss=0.2835, Test Acc=0.9082
# Epoch 106: Train Loss=0.1836, Train Acc=0.9464, Test Loss=0.2962, Test Acc=0.8980
# Epoch 107: Train Loss=0.1786, Train Acc=0.9451, Test Loss=0.2819, Test Acc=0.9133
# Epoch 108: Train Loss=0.1731, Train Acc=0.9540, Test Loss=0.2795, Test Acc=0.9082
# Epoch 109: Train Loss=0.1720, Train Acc=0.9540, Test Loss=0.2775, Test Acc=0.9133
# Epoch 110: Train Loss=0.1708, Train Acc=0.9566, Test Loss=0.2785, Test Acc=0.9133
# Epoch 111: Train Loss=0.1785, Train Acc=0.9451, Test Loss=0.2763, Test Acc=0.9133
# Epoch 112: Train Loss=0.1675, Train Acc=0.9566, Test Loss=0.2744, Test Acc=0.9184
# Epoch 113: Train Loss=0.1668, Train Acc=0.9553, Test Loss=0.2723, Test Acc=0.9184
# Epoch 114: Train Loss=0.1617, Train Acc=0.9566, Test Loss=0.2751, Test Acc=0.9235
# Epoch 115: Train Loss=0.1609, Train Acc=0.9579, Test Loss=0.2749, Test Acc=0.9235
# Epoch 116: Train Loss=0.1561, Train Acc=0.9579, Test Loss=0.2665, Test Acc=0.9184
# Epoch 117: Train Loss=0.1547, Train Acc=0.9630, Test Loss=0.2626, Test Acc=0.9235
# Epoch 118: Train Loss=0.1550, Train Acc=0.9630, Test Loss=0.2700, Test Acc=0.9184
# Epoch 119: Train Loss=0.1527, Train Acc=0.9591, Test Loss=0.2646, Test Acc=0.9184
# Epoch 120: Train Loss=0.1537, Train Acc=0.9630, Test Loss=0.2611, Test Acc=0.9286
# Epoch 121: Train Loss=0.1522, Train Acc=0.9668, Test Loss=0.2598, Test Acc=0.9337
# Epoch 122: Train Loss=0.1471, Train Acc=0.9693, Test Loss=0.2589, Test Acc=0.9235
# Epoch 123: Train Loss=0.1440, Train Acc=0.9719, Test Loss=0.2611, Test Acc=0.9286
# Epoch 124: Train Loss=0.1464, Train Acc=0.9617, Test Loss=0.2717, Test Acc=0.9235
# Epoch 125: Train Loss=0.1397, Train Acc=0.9668, Test Loss=0.2544, Test Acc=0.9337
# Epoch 126: Train Loss=0.1351, Train Acc=0.9668, Test Loss=0.2515, Test Acc=0.9235
# Epoch 127: Train Loss=0.1358, Train Acc=0.9642, Test Loss=0.2586, Test Acc=0.9235
# Epoch 128: Train Loss=0.1303, Train Acc=0.9757, Test Loss=0.2497, Test Acc=0.9388
# Epoch 129: Train Loss=0.1272, Train Acc=0.9757, Test Loss=0.2466, Test Acc=0.9286
# Epoch 130: Train Loss=0.1316, Train Acc=0.9719, Test Loss=0.2500, Test Acc=0.9286
# Epoch 131: Train Loss=0.1284, Train Acc=0.9732, Test Loss=0.2416, Test Acc=0.9286
# Epoch 132: Train Loss=0.1254, Train Acc=0.9745, Test Loss=0.2451, Test Acc=0.9337
# Epoch 133: Train Loss=0.1219, Train Acc=0.9834, Test Loss=0.2426, Test Acc=0.9388
# Epoch 134: Train Loss=0.1252, Train Acc=0.9706, Test Loss=0.2465, Test Acc=0.9337
# Epoch 135: Train Loss=0.1200, Train Acc=0.9732, Test Loss=0.2482, Test Acc=0.9388
# Epoch 136: Train Loss=0.1221, Train Acc=0.9732, Test Loss=0.2387, Test Acc=0.9388
# Epoch 137: Train Loss=0.1151, Train Acc=0.9821, Test Loss=0.2399, Test Acc=0.9337
# Epoch 138: Train Loss=0.1226, Train Acc=0.9770, Test Loss=0.2434, Test Acc=0.9388
# Epoch 139: Train Loss=0.1161, Train Acc=0.9745, Test Loss=0.2478, Test Acc=0.9388
# Epoch 140: Train Loss=0.1164, Train Acc=0.9783, Test Loss=0.2441, Test Acc=0.9388
# Epoch 141: Train Loss=0.1111, Train Acc=0.9860, Test Loss=0.2315, Test Acc=0.9439
# Epoch 142: Train Loss=0.1082, Train Acc=0.9847, Test Loss=0.2341, Test Acc=0.9439
# Epoch 143: Train Loss=0.1073, Train Acc=0.9860, Test Loss=0.2373, Test Acc=0.9388
# Epoch 144: Train Loss=0.1043, Train Acc=0.9872, Test Loss=0.2476, Test Acc=0.9388
# Epoch 145: Train Loss=0.1048, Train Acc=0.9834, Test Loss=0.2318, Test Acc=0.9388
# Epoch 146: Train Loss=0.1031, Train Acc=0.9834, Test Loss=0.2291, Test Acc=0.9337
# Epoch 147: Train Loss=0.1021, Train Acc=0.9847, Test Loss=0.2289, Test Acc=0.9286
# Epoch 148: Train Loss=0.0985, Train Acc=0.9860, Test Loss=0.2299, Test Acc=0.9388
# Epoch 149: Train Loss=0.0991, Train Acc=0.9872, Test Loss=0.2256, Test Acc=0.9388
# Epoch 150: Train Loss=0.0970, Train Acc=0.9860, Test Loss=0.2385, Test Acc=0.9388
# Epoch 151: Train Loss=0.0969, Train Acc=0.9885, Test Loss=0.2342, Test Acc=0.9388
# Epoch 152: Train Loss=0.0982, Train Acc=0.9834, Test Loss=0.2228, Test Acc=0.9337
# Epoch 153: Train Loss=0.0963, Train Acc=0.9898, Test Loss=0.2223, Test Acc=0.9439
# Epoch 154: Train Loss=0.0875, Train Acc=0.9936, Test Loss=0.2232, Test Acc=0.9388
# Epoch 155: Train Loss=0.0894, Train Acc=0.9911, Test Loss=0.2250, Test Acc=0.9439
# Epoch 156: Train Loss=0.0897, Train Acc=0.9898, Test Loss=0.2170, Test Acc=0.9439
# Epoch 157: Train Loss=0.0881, Train Acc=0.9911, Test Loss=0.2147, Test Acc=0.9439
# Epoch 158: Train Loss=0.0882, Train Acc=0.9898, Test Loss=0.2146, Test Acc=0.9439
# Epoch 159: Train Loss=0.0823, Train Acc=0.9936, Test Loss=0.2122, Test Acc=0.9439
# Epoch 160: Train Loss=0.0827, Train Acc=0.9911, Test Loss=0.2303, Test Acc=0.9388
# Epoch 161: Train Loss=0.0777, Train Acc=0.9936, Test Loss=0.2214, Test Acc=0.9439
# Epoch 162: Train Loss=0.0841, Train Acc=0.9885, Test Loss=0.2123, Test Acc=0.9439
# Epoch 163: Train Loss=0.0777, Train Acc=0.9949, Test Loss=0.2184, Test Acc=0.9490
# Epoch 164: Train Loss=0.0802, Train Acc=0.9936, Test Loss=0.2202, Test Acc=0.9388
# Epoch 165: Train Loss=0.0788, Train Acc=0.9923, Test Loss=0.2257, Test Acc=0.9388
# Epoch 166: Train Loss=0.0772, Train Acc=0.9923, Test Loss=0.2093, Test Acc=0.9439
# Epoch 167: Train Loss=0.0765, Train Acc=0.9923, Test Loss=0.2118, Test Acc=0.9439
# Epoch 168: Train Loss=0.0742, Train Acc=0.9923, Test Loss=0.2264, Test Acc=0.9490
# Epoch 169: Train Loss=0.0797, Train Acc=0.9885, Test Loss=0.2090, Test Acc=0.9388
# Epoch 170: Train Loss=0.0729, Train Acc=0.9949, Test Loss=0.2073, Test Acc=0.9388
# Epoch 171: Train Loss=0.0726, Train Acc=0.9987, Test Loss=0.2355, Test Acc=0.9388
# Epoch 172: Train Loss=0.0701, Train Acc=0.9962, Test Loss=0.2112, Test Acc=0.9490
# Epoch 173: Train Loss=0.0701, Train Acc=0.9962, Test Loss=0.2044, Test Acc=0.9439
# Epoch 174: Train Loss=0.0670, Train Acc=0.9974, Test Loss=0.2150, Test Acc=0.9439
# Epoch 175: Train Loss=0.0696, Train Acc=0.9911, Test Loss=0.2175, Test Acc=0.9439
# Epoch 176: Train Loss=0.0680, Train Acc=0.9936, Test Loss=0.2060, Test Acc=0.9439
# Epoch 177: Train Loss=0.0670, Train Acc=0.9936, Test Loss=0.2020, Test Acc=0.9439
# Epoch 178: Train Loss=0.0631, Train Acc=0.9974, Test Loss=0.2176, Test Acc=0.9490
# Epoch 179: Train Loss=0.0671, Train Acc=0.9936, Test Loss=0.2048, Test Acc=0.9388
# Epoch 180: Train Loss=0.0607, Train Acc=1.0000, Test Loss=0.2054, Test Acc=0.9439
# Epoch 181: Train Loss=0.0625, Train Acc=0.9974, Test Loss=0.2232, Test Acc=0.9439
# Epoch 182: Train Loss=0.0603, Train Acc=0.9987, Test Loss=0.2036, Test Acc=0.9439
# Epoch 183: Train Loss=0.0598, Train Acc=0.9962, Test Loss=0.2027, Test Acc=0.9439
# Epoch 184: Train Loss=0.0590, Train Acc=0.9974, Test Loss=0.2258, Test Acc=0.9388
# Epoch 185: Train Loss=0.0551, Train Acc=1.0000, Test Loss=0.1974, Test Acc=0.9490
# Epoch 186: Train Loss=0.0619, Train Acc=0.9962, Test Loss=0.2073, Test Acc=0.9439
# Epoch 187: Train Loss=0.0551, Train Acc=0.9974, Test Loss=0.2169, Test Acc=0.9490
# Epoch 188: Train Loss=0.0597, Train Acc=0.9962, Test Loss=0.1996, Test Acc=0.9439
# Epoch 189: Train Loss=0.0552, Train Acc=0.9987, Test Loss=0.1999, Test Acc=0.9439
# Epoch 190: Train Loss=0.0523, Train Acc=1.0000, Test Loss=0.2027, Test Acc=0.9439
# Epoch 191: Train Loss=0.0562, Train Acc=1.0000, Test Loss=0.2165, Test Acc=0.9439
# Epoch 192: Train Loss=0.0545, Train Acc=0.9987, Test Loss=0.2032, Test Acc=0.9439
# Epoch 193: Train Loss=0.0502, Train Acc=0.9987, Test Loss=0.1960, Test Acc=0.9490
# Epoch 194: Train Loss=0.0510, Train Acc=1.0000, Test Loss=0.1995, Test Acc=0.9439
# Epoch 195: Train Loss=0.0514, Train Acc=0.9987, Test Loss=0.1957, Test Acc=0.9490
# Epoch 196: Train Loss=0.0480, Train Acc=0.9987, Test Loss=0.1961, Test Acc=0.9439
# Epoch 197: Train Loss=0.0505, Train Acc=1.0000, Test Loss=0.2063, Test Acc=0.9490
# Epoch 198: Train Loss=0.0516, Train Acc=0.9974, Test Loss=0.2250, Test Acc=0.9439
# Epoch 199: Train Loss=0.0541, Train Acc=0.9987, Test Loss=0.2114, Test Acc=0.9490
# Epoch 200: Train Loss=0.0515, Train Acc=1.0000, Test Loss=0.1991, Test Acc=0.9490
# Epoch 201: Train Loss=0.0480, Train Acc=0.9987, Test Loss=0.2015, Test Acc=0.9439
# Epoch 202: Train Loss=0.0474, Train Acc=1.0000, Test Loss=0.2173, Test Acc=0.9490
# Epoch 203: Train Loss=0.0480, Train Acc=0.9974, Test Loss=0.1904, Test Acc=0.9490
# Epoch 204: Train Loss=0.0448, Train Acc=1.0000, Test Loss=0.1939, Test Acc=0.9439
# Epoch 205: Train Loss=0.0527, Train Acc=0.9949, Test Loss=0.1975, Test Acc=0.9541
# Epoch 206: Train Loss=0.0553, Train Acc=0.9974, Test Loss=0.2080, Test Acc=0.9490
# Epoch 207: Train Loss=0.0497, Train Acc=0.9962, Test Loss=0.2291, Test Acc=0.9439
# Epoch 208: Train Loss=0.0467, Train Acc=1.0000, Test Loss=0.1933, Test Acc=0.9439
# Epoch 209: Train Loss=0.0425, Train Acc=1.0000, Test Loss=0.2041, Test Acc=0.9490
# Epoch 210: Train Loss=0.0396, Train Acc=1.0000, Test Loss=0.2074, Test Acc=0.9490
# Epoch 211: Train Loss=0.0402, Train Acc=1.0000, Test Loss=0.1951, Test Acc=0.9541
# Epoch 212: Train Loss=0.0407, Train Acc=1.0000, Test Loss=0.1999, Test Acc=0.9541
# Epoch 213: Train Loss=0.0368, Train Acc=1.0000, Test Loss=0.1965, Test Acc=0.9490
# Epoch 214: Train Loss=0.0406, Train Acc=1.0000, Test Loss=0.1950, Test Acc=0.9541
# Epoch 215: Train Loss=0.0370, Train Acc=1.0000, Test Loss=0.2019, Test Acc=0.9490
# Epoch 216: Train Loss=0.0352, Train Acc=1.0000, Test Loss=0.2144, Test Acc=0.9490
# Epoch 217: Train Loss=0.0378, Train Acc=1.0000, Test Loss=0.2095, Test Acc=0.9490
# Epoch 218: Train Loss=0.0358, Train Acc=0.9987, Test Loss=0.1966, Test Acc=0.9541
# Epoch 219: Train Loss=0.0338, Train Acc=1.0000, Test Loss=0.1973, Test Acc=0.9541
# Epoch 220: Train Loss=0.0346, Train Acc=1.0000, Test Loss=0.2029, Test Acc=0.9490
# Epoch 221: Train Loss=0.0349, Train Acc=1.0000, Test Loss=0.2010, Test Acc=0.9541
# Epoch 222: Train Loss=0.0325, Train Acc=1.0000, Test Loss=0.2031, Test Acc=0.9490
# Epoch 223: Train Loss=0.0358, Train Acc=1.0000, Test Loss=0.1942, Test Acc=0.9541
# Epoch 224: Train Loss=0.0324, Train Acc=1.0000, Test Loss=0.2044, Test Acc=0.9490
# Epoch 225: Train Loss=0.0339, Train Acc=1.0000, Test Loss=0.1908, Test Acc=0.9541
# Epoch 226: Train Loss=0.0383, Train Acc=1.0000, Test Loss=0.1895, Test Acc=0.9541
# Epoch 227: Train Loss=0.0316, Train Acc=1.0000, Test Loss=0.1902, Test Acc=0.9541
# Epoch 228: Train Loss=0.0355, Train Acc=0.9987, Test Loss=0.1921, Test Acc=0.9490
# Epoch 229: Train Loss=0.0326, Train Acc=1.0000, Test Loss=0.2229, Test Acc=0.9490
# Epoch 230: Train Loss=0.0360, Train Acc=1.0000, Test Loss=0.2001, Test Acc=0.9541
# Epoch 231: Train Loss=0.0324, Train Acc=1.0000, Test Loss=0.1988, Test Acc=0.9541
# Epoch 232: Train Loss=0.0283, Train Acc=1.0000, Test Loss=0.2046, Test Acc=0.9439
# Epoch 233: Train Loss=0.0295, Train Acc=1.0000, Test Loss=0.1967, Test Acc=0.9541
# Epoch 234: Train Loss=0.0301, Train Acc=1.0000, Test Loss=0.2013, Test Acc=0.9541
# Epoch 235: Train Loss=0.0346, Train Acc=0.9974, Test Loss=0.2037, Test Acc=0.9541
# Epoch 236: Train Loss=0.0373, Train Acc=0.9987, Test Loss=0.2117, Test Acc=0.9388
# Epoch 237: Train Loss=0.0287, Train Acc=1.0000, Test Loss=0.2015, Test Acc=0.9541
# Epoch 238: Train Loss=0.0329, Train Acc=0.9987, Test Loss=0.1991, Test Acc=0.9541
# Epoch 239: Train Loss=0.0303, Train Acc=1.0000, Test Loss=0.2171, Test Acc=0.9490
# Epoch 240: Train Loss=0.0318, Train Acc=1.0000, Test Loss=0.2118, Test Acc=0.9490
# Epoch 241: Train Loss=0.0294, Train Acc=1.0000, Test Loss=0.1960, Test Acc=0.9541
# Epoch 242: Train Loss=0.0306, Train Acc=1.0000, Test Loss=0.2005, Test Acc=0.9541
# Epoch 243: Train Loss=0.0266, Train Acc=1.0000, Test Loss=0.2106, Test Acc=0.9490
# Epoch 244: Train Loss=0.0289, Train Acc=1.0000, Test Loss=0.2132, Test Acc=0.9490
# Epoch 245: Train Loss=0.0285, Train Acc=1.0000, Test Loss=0.1917, Test Acc=0.9541
# Epoch 246: Train Loss=0.0280, Train Acc=1.0000, Test Loss=0.1912, Test Acc=0.9541
# Epoch 247: Train Loss=0.0254, Train Acc=1.0000, Test Loss=0.2038, Test Acc=0.9490
# Epoch 248: Train Loss=0.0280, Train Acc=1.0000, Test Loss=0.1980, Test Acc=0.9541
# Epoch 249: Train Loss=0.0246, Train Acc=1.0000, Test Loss=0.1965, Test Acc=0.9541
# Epoch 250: Train Loss=0.0235, Train Acc=1.0000, Test Loss=0.2002, Test Acc=0.9541
# Epoch 251: Train Loss=0.0230, Train Acc=1.0000, Test Loss=0.1968, Test Acc=0.9490
# Epoch 252: Train Loss=0.0240, Train Acc=1.0000, Test Loss=0.2054, Test Acc=0.9439
# Epoch 253: Train Loss=0.0245, Train Acc=1.0000, Test Loss=0.2014, Test Acc=0.9541
# Epoch 254: Train Loss=0.0221, Train Acc=1.0000, Test Loss=0.1913, Test Acc=0.9541
# Epoch 255: Train Loss=0.0227, Train Acc=1.0000, Test Loss=0.2159, Test Acc=0.9490
# Epoch 256: Train Loss=0.0222, Train Acc=1.0000, Test Loss=0.1951, Test Acc=0.9592
# Epoch 257: Train Loss=0.0267, Train Acc=1.0000, Test Loss=0.1870, Test Acc=0.9643
# Epoch 258: Train Loss=0.0231, Train Acc=1.0000, Test Loss=0.1930, Test Acc=0.9541
# Epoch 259: Train Loss=0.0201, Train Acc=1.0000, Test Loss=0.2027, Test Acc=0.9541
# Epoch 260: Train Loss=0.0237, Train Acc=1.0000, Test Loss=0.2041, Test Acc=0.9490
# Epoch 261: Train Loss=0.0220, Train Acc=1.0000, Test Loss=0.1867, Test Acc=0.9643
# Epoch 262: Train Loss=0.0220, Train Acc=1.0000, Test Loss=0.1999, Test Acc=0.9592
# Epoch 263: Train Loss=0.0229, Train Acc=1.0000, Test Loss=0.2038, Test Acc=0.9592
# Epoch 264: Train Loss=0.0246, Train Acc=1.0000, Test Loss=0.2037, Test Acc=0.9592
# Epoch 265: Train Loss=0.0195, Train Acc=1.0000, Test Loss=0.1962, Test Acc=0.9541
# Epoch 266: Train Loss=0.0222, Train Acc=1.0000, Test Loss=0.1945, Test Acc=0.9592
# Epoch 267: Train Loss=0.0206, Train Acc=1.0000, Test Loss=0.2154, Test Acc=0.9592
# Epoch 268: Train Loss=0.0196, Train Acc=1.0000, Test Loss=0.1929, Test Acc=0.9592
# Epoch 269: Train Loss=0.0201, Train Acc=1.0000, Test Loss=0.2104, Test Acc=0.9592
# Epoch 270: Train Loss=0.0194, Train Acc=1.0000, Test Loss=0.1994, Test Acc=0.9592
# Epoch 271: Train Loss=0.0186, Train Acc=1.0000, Test Loss=0.2034, Test Acc=0.9541
# Epoch 272: Train Loss=0.0223, Train Acc=1.0000, Test Loss=0.1880, Test Acc=0.9643
# Epoch 273: Train Loss=0.0204, Train Acc=1.0000, Test Loss=0.2040, Test Acc=0.9592
# Epoch 274: Train Loss=0.0178, Train Acc=1.0000, Test Loss=0.2087, Test Acc=0.9592
# Epoch 275: Train Loss=0.0205, Train Acc=1.0000, Test Loss=0.2043, Test Acc=0.9541
# Epoch 276: Train Loss=0.0201, Train Acc=1.0000, Test Loss=0.1908, Test Acc=0.9643
# Epoch 277: Train Loss=0.0176, Train Acc=1.0000, Test Loss=0.1996, Test Acc=0.9541
# Epoch 278: Train Loss=0.0185, Train Acc=1.0000, Test Loss=0.2290, Test Acc=0.9490
# Epoch 279: Train Loss=0.0228, Train Acc=1.0000, Test Loss=0.2033, Test Acc=0.9541
# Epoch 280: Train Loss=0.0195, Train Acc=1.0000, Test Loss=0.2061, Test Acc=0.9592
# Epoch 281: Train Loss=0.0183, Train Acc=1.0000, Test Loss=0.2048, Test Acc=0.9592
# Epoch 282: Train Loss=0.0174, Train Acc=1.0000, Test Loss=0.1975, Test Acc=0.9592
# Epoch 283: Train Loss=0.0203, Train Acc=1.0000, Test Loss=0.2246, Test Acc=0.9490
# Epoch 284: Train Loss=0.0157, Train Acc=1.0000, Test Loss=0.2081, Test Acc=0.9592
# Epoch 285: Train Loss=0.0169, Train Acc=1.0000, Test Loss=0.1920, Test Acc=0.9541
# Epoch 286: Train Loss=0.0175, Train Acc=1.0000, Test Loss=0.2291, Test Acc=0.9490
# Epoch 287: Train Loss=0.0164, Train Acc=1.0000, Test Loss=0.1973, Test Acc=0.9541
# Epoch 288: Train Loss=0.0163, Train Acc=1.0000, Test Loss=0.2050, Test Acc=0.9592
# Epoch 289: Train Loss=0.0168, Train Acc=1.0000, Test Loss=0.2009, Test Acc=0.9541
# Epoch 290: Train Loss=0.0153, Train Acc=1.0000, Test Loss=0.1968, Test Acc=0.9541
# Epoch 291: Train Loss=0.0186, Train Acc=1.0000, Test Loss=0.2367, Test Acc=0.9439
# Epoch 292: Train Loss=0.0156, Train Acc=1.0000, Test Loss=0.2013, Test Acc=0.9541
# Epoch 293: Train Loss=0.0142, Train Acc=1.0000, Test Loss=0.2003, Test Acc=0.9541
# Epoch 294: Train Loss=0.0157, Train Acc=1.0000, Test Loss=0.2074, Test Acc=0.9541
# Epoch 295: Train Loss=0.0142, Train Acc=1.0000, Test Loss=0.2151, Test Acc=0.9541
# Epoch 296: Train Loss=0.0170, Train Acc=1.0000, Test Loss=0.2333, Test Acc=0.9490
# Epoch 297: Train Loss=0.0171, Train Acc=1.0000, Test Loss=0.2184, Test Acc=0.9541
# Epoch 298: Train Loss=0.0143, Train Acc=1.0000, Test Loss=0.1939, Test Acc=0.9643
# Epoch 299: Train Loss=0.0142, Train Acc=1.0000, Test Loss=0.1990, Test Acc=0.9541
# Epoch 300: Train Loss=0.0153, Train Acc=1.0000, Test Loss=0.2265, Test Acc=0.9490
# Epoch 301: Train Loss=0.0153, Train Acc=1.0000, Test Loss=0.1957, Test Acc=0.9541
# Epoch 302: Train Loss=0.0157, Train Acc=1.0000, Test Loss=0.2239, Test Acc=0.9490
# Epoch 303: Train Loss=0.0146, Train Acc=1.0000, Test Loss=0.2259, Test Acc=0.9541
# Epoch 304: Train Loss=0.0148, Train Acc=1.0000, Test Loss=0.2089, Test Acc=0.9541
# Epoch 305: Train Loss=0.0143, Train Acc=1.0000, Test Loss=0.2447, Test Acc=0.9490
# Epoch 306: Train Loss=0.0152, Train Acc=1.0000, Test Loss=0.2029, Test Acc=0.9541
# Epoch 307: Train Loss=0.0131, Train Acc=1.0000, Test Loss=0.2004, Test Acc=0.9490
# Epoch 308: Train Loss=0.0144, Train Acc=1.0000, Test Loss=0.2048, Test Acc=0.9592
# Epoch 309: Train Loss=0.0142, Train Acc=1.0000, Test Loss=0.2053, Test Acc=0.9592
# Epoch 310: Train Loss=0.0144, Train Acc=1.0000, Test Loss=0.2055, Test Acc=0.9541
# Epoch 311: Train Loss=0.0155, Train Acc=1.0000, Test Loss=0.2002, Test Acc=0.9541
# Epoch 312: Train Loss=0.0147, Train Acc=1.0000, Test Loss=0.2050, Test Acc=0.9541
# Epoch 313: Train Loss=0.0146, Train Acc=1.0000, Test Loss=0.2269, Test Acc=0.9490
# Epoch 314: Train Loss=0.0145, Train Acc=1.0000, Test Loss=0.2734, Test Acc=0.9286
# Epoch 315: Train Loss=0.0147, Train Acc=1.0000, Test Loss=0.2059, Test Acc=0.9541
# Epoch 316: Train Loss=0.0169, Train Acc=1.0000, Test Loss=0.2090, Test Acc=0.9490
# Epoch 317: Train Loss=0.0194, Train Acc=0.9987, Test Loss=0.2080, Test Acc=0.9388
# Epoch 318: Train Loss=0.0140, Train Acc=1.0000, Test Loss=0.2858, Test Acc=0.9337
# Epoch 319: Train Loss=0.0126, Train Acc=1.0000, Test Loss=0.2381, Test Acc=0.9439
# Epoch 320: Train Loss=0.0115, Train Acc=1.0000, Test Loss=0.2095, Test Acc=0.9541
# Epoch 321: Train Loss=0.0129, Train Acc=1.0000, Test Loss=0.2032, Test Acc=0.9541
# Epoch 322: Train Loss=0.0130, Train Acc=1.0000, Test Loss=0.2024, Test Acc=0.9541
# Epoch 323: Train Loss=0.0124, Train Acc=1.0000, Test Loss=0.2093, Test Acc=0.9541
# Epoch 324: Train Loss=0.0134, Train Acc=1.0000, Test Loss=0.2135, Test Acc=0.9592
# Epoch 325: Train Loss=0.0109, Train Acc=1.0000, Test Loss=0.2169, Test Acc=0.9592
# Epoch 326: Train Loss=0.0112, Train Acc=1.0000, Test Loss=0.2081, Test Acc=0.9541
# Epoch 327: Train Loss=0.0120, Train Acc=1.0000, Test Loss=0.2201, Test Acc=0.9592
# Epoch 328: Train Loss=0.0099, Train Acc=1.0000, Test Loss=0.2171, Test Acc=0.9592
# Epoch 329: Train Loss=0.0107, Train Acc=1.0000, Test Loss=0.2043, Test Acc=0.9541
# Epoch 330: Train Loss=0.0123, Train Acc=1.0000, Test Loss=0.2101, Test Acc=0.9592
# Epoch 331: Train Loss=0.0128, Train Acc=1.0000, Test Loss=0.2233, Test Acc=0.9439
# Epoch 332: Train Loss=0.0105, Train Acc=1.0000, Test Loss=0.2413, Test Acc=0.9541
# Epoch 333: Train Loss=0.0119, Train Acc=1.0000, Test Loss=0.2001, Test Acc=0.9541
# Epoch 334: Train Loss=0.0099, Train Acc=1.0000, Test Loss=0.2314, Test Acc=0.9490
# Epoch 335: Train Loss=0.0090, Train Acc=1.0000, Test Loss=0.2155, Test Acc=0.9592
# Epoch 336: Train Loss=0.0105, Train Acc=1.0000, Test Loss=0.2087, Test Acc=0.9541
# Epoch 337: Train Loss=0.0122, Train Acc=0.9987, Test Loss=0.2088, Test Acc=0.9592
# Epoch 338: Train Loss=0.0105, Train Acc=1.0000, Test Loss=0.2460, Test Acc=0.9490
# Epoch 339: Train Loss=0.0100, Train Acc=1.0000, Test Loss=0.2010, Test Acc=0.9541
# Epoch 340: Train Loss=0.0089, Train Acc=1.0000, Test Loss=0.2208, Test Acc=0.9592
# Epoch 341: Train Loss=0.0079, Train Acc=1.0000, Test Loss=0.2206, Test Acc=0.9592
# Epoch 342: Train Loss=0.0098, Train Acc=1.0000, Test Loss=0.2069, Test Acc=0.9541
# Epoch 343: Train Loss=0.0092, Train Acc=1.0000, Test Loss=0.2193, Test Acc=0.9592
# Epoch 344: Train Loss=0.0083, Train Acc=1.0000, Test Loss=0.2166, Test Acc=0.9592
# Epoch 345: Train Loss=0.0113, Train Acc=1.0000, Test Loss=0.2141, Test Acc=0.9592
# Epoch 346: Train Loss=0.0089, Train Acc=1.0000, Test Loss=0.2018, Test Acc=0.9592
# Epoch 347: Train Loss=0.0100, Train Acc=1.0000, Test Loss=0.1987, Test Acc=0.9541
# Epoch 348: Train Loss=0.0110, Train Acc=1.0000, Test Loss=0.2185, Test Acc=0.9592
# Epoch 349: Train Loss=0.0086, Train Acc=1.0000, Test Loss=0.2227, Test Acc=0.9592
# Epoch 350: Train Loss=0.0115, Train Acc=1.0000, Test Loss=0.2094, Test Acc=0.9592
# Epoch 351: Train Loss=0.0092, Train Acc=1.0000, Test Loss=0.2286, Test Acc=0.9490
# Epoch 352: Train Loss=0.0085, Train Acc=1.0000, Test Loss=0.2078, Test Acc=0.9541
# Epoch 353: Train Loss=0.0091, Train Acc=1.0000, Test Loss=0.2077, Test Acc=0.9541
# Epoch 354: Train Loss=0.0074, Train Acc=1.0000, Test Loss=0.2081, Test Acc=0.9592
# Epoch 355: Train Loss=0.0088, Train Acc=1.0000, Test Loss=0.2156, Test Acc=0.9592
# Epoch 356: Train Loss=0.0088, Train Acc=1.0000, Test Loss=0.2278, Test Acc=0.9592
# Epoch 357: Train Loss=0.0091, Train Acc=1.0000, Test Loss=0.2132, Test Acc=0.9592
# Epoch 358: Train Loss=0.0077, Train Acc=1.0000, Test Loss=0.2192, Test Acc=0.9592
# Epoch 359: Train Loss=0.0080, Train Acc=1.0000, Test Loss=0.2195, Test Acc=0.9592
# Epoch 360: Train Loss=0.0079, Train Acc=1.0000, Test Loss=0.2096, Test Acc=0.9592
# Epoch 361: Train Loss=0.0070, Train Acc=1.0000, Test Loss=0.2109, Test Acc=0.9592
# Epoch 362: Train Loss=0.0070, Train Acc=1.0000, Test Loss=0.2141, Test Acc=0.9541
# Epoch 363: Train Loss=0.0085, Train Acc=1.0000, Test Loss=0.2283, Test Acc=0.9541
# Epoch 364: Train Loss=0.0068, Train Acc=1.0000, Test Loss=0.2156, Test Acc=0.9541
# Epoch 365: Train Loss=0.0071, Train Acc=1.0000, Test Loss=0.2080, Test Acc=0.9541
# Epoch 366: Train Loss=0.0084, Train Acc=1.0000, Test Loss=0.2163, Test Acc=0.9541
# Epoch 367: Train Loss=0.0083, Train Acc=1.0000, Test Loss=0.2093, Test Acc=0.9592
# Epoch 368: Train Loss=0.0077, Train Acc=1.0000, Test Loss=0.2188, Test Acc=0.9592
# Epoch 369: Train Loss=0.0063, Train Acc=1.0000, Test Loss=0.2206, Test Acc=0.9592
# Epoch 370: Train Loss=0.0073, Train Acc=1.0000, Test Loss=0.2263, Test Acc=0.9592
# Epoch 371: Train Loss=0.0083, Train Acc=1.0000, Test Loss=0.2188, Test Acc=0.9592
# Epoch 372: Train Loss=0.0076, Train Acc=1.0000, Test Loss=0.2092, Test Acc=0.9643
# Epoch 373: Train Loss=0.0076, Train Acc=1.0000, Test Loss=0.2142, Test Acc=0.9643
# Epoch 374: Train Loss=0.0066, Train Acc=1.0000, Test Loss=0.2300, Test Acc=0.9592
# Epoch 375: Train Loss=0.0074, Train Acc=1.0000, Test Loss=0.2163, Test Acc=0.9592
# Epoch 376: Train Loss=0.0070, Train Acc=1.0000, Test Loss=0.2032, Test Acc=0.9592
# Epoch 377: Train Loss=0.0076, Train Acc=1.0000, Test Loss=0.2266, Test Acc=0.9592
# Epoch 378: Train Loss=0.0062, Train Acc=1.0000, Test Loss=0.2574, Test Acc=0.9490
# Epoch 379: Train Loss=0.0070, Train Acc=1.0000, Test Loss=0.2168, Test Acc=0.9592
# Epoch 380: Train Loss=0.0072, Train Acc=1.0000, Test Loss=0.1997, Test Acc=0.9592
# Epoch 381: Train Loss=0.0072, Train Acc=1.0000, Test Loss=0.2083, Test Acc=0.9541
# Epoch 382: Train Loss=0.0069, Train Acc=1.0000, Test Loss=0.2280, Test Acc=0.9592
# Epoch 383: Train Loss=0.0065, Train Acc=1.0000, Test Loss=0.2402, Test Acc=0.9541
# Epoch 384: Train Loss=0.0068, Train Acc=1.0000, Test Loss=0.2211, Test Acc=0.9592
# Epoch 385: Train Loss=0.0085, Train Acc=1.0000, Test Loss=0.2073, Test Acc=0.9592
# Epoch 386: Train Loss=0.0072, Train Acc=1.0000, Test Loss=0.2265, Test Acc=0.9592
# Epoch 387: Train Loss=0.0059, Train Acc=1.0000, Test Loss=0.2310, Test Acc=0.9592
# Epoch 388: Train Loss=0.0076, Train Acc=1.0000, Test Loss=0.2097, Test Acc=0.9643
# Epoch 389: Train Loss=0.0062, Train Acc=1.0000, Test Loss=0.2072, Test Acc=0.9643
# Epoch 390: Train Loss=0.0054, Train Acc=1.0000, Test Loss=0.2175, Test Acc=0.9541
# Epoch 391: Train Loss=0.0052, Train Acc=1.0000, Test Loss=0.2357, Test Acc=0.9592
# Epoch 392: Train Loss=0.0082, Train Acc=1.0000, Test Loss=0.2113, Test Acc=0.9694
# Epoch 393: Train Loss=0.0072, Train Acc=1.0000, Test Loss=0.2078, Test Acc=0.9694
# Epoch 394: Train Loss=0.0069, Train Acc=1.0000, Test Loss=0.2273, Test Acc=0.9541
# Epoch 395: Train Loss=0.0055, Train Acc=1.0000, Test Loss=0.2226, Test Acc=0.9592
# Epoch 396: Train Loss=0.0058, Train Acc=1.0000, Test Loss=0.2165, Test Acc=0.9541
# Epoch 397: Train Loss=0.0061, Train Acc=1.0000, Test Loss=0.2158, Test Acc=0.9643
# Epoch 398: Train Loss=0.0057, Train Acc=1.0000, Test Loss=0.2294, Test Acc=0.9592
# Epoch 399: Train Loss=0.0076, Train Acc=1.0000, Test Loss=0.2408, Test Acc=0.9592
# Epoch 400: Train Loss=0.0052, Train Acc=1.0000, Test Loss=0.2177, Test Acc=0.9541
#
# 📊 Confusion Matrix at Highest Accuracy (Epoch 392):
# [[ 58   5]
#  [  1 132]]
#
# 📌 TP/FP/TN/FN Indices at Epoch 392:
# ✅ TP: [199, 543, 174, 66, 495, 548, 601, 158, 67, 531, 231, 408, 578, 294, 88, 96, 306, 513, 611, 357, 286, 23, 30, 447, 244, 532, 516, 439, 299, 298, 275, 213, 638, 559, 120, 590, 342, 596, 39, 309, 312, 59, 394, 290, 277, 209, 405, 507, 585, 433, 411, 70, 136, 346, 584, 462, 63, 589, 218, 449, 365, 485, 468, 430, 86, 331, 626, 334, 107, 260, 352, 529, 655, 678, 362, 538, 518, 55, 265, 296, 72, 237, 44, 210, 292, 665, 333, 664, 631, 310, 370, 254, 628, 280, 60, 528, 420, 139, 581, 281, 110, 442, 319, 617, 440, 198, 381, 137, 486, 344, 184, 544, 168, 350, 328, 78, 29, 261, 630, 165, 689, 436, 65, 141, 684, 673, 404, 650, 49, 363, 361, 525]
# ❌ FP: [929, 974, 715, 864, 972]
# ✅ TN: [751, 879, 745, 976, 851, 761, 848, 964, 873, 941, 717, 888, 793, 756, 957, 713, 723, 808, 894, 741, 891, 755, 802, 968, 927, 798, 787, 903, 970, 847, 952, 758, 923, 722, 707, 921, 833, 708, 876, 783, 819, 696, 735, 904, 977, 799, 809, 737, 753, 767, 710, 759, 765, 797, 712, 954, 884, 973]
# ❌ FN: [76]
# 💾 Indices saved to: TP_FP_TN_FN_Epoch_392.pkl
# 🖼️ Confusion matrix saved as Confusion_Matrix_Epoch_392.png
# 🖼️ Metrics plot saved as A+B_OneHot_64_NoWD_metrics_plot.png
# 📊 Metrics saved to A+B_OneHot_64_NoWD.xlsx
