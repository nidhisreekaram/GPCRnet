# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.nn import GINConv, global_mean_pool
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix,
    ConfusionMatrixDisplay, precision_score,
    recall_score, f1_score
)
import matplotlib.pyplot as plt
import pickle
import numpy as np
import random
import pandas as pd
import os

# === Reproducibility ===
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)

# === Load Pickle Dataset ===
def load_pytorch_dataset(file_path):
    with open(file_path, 'rb') as f:
        dataset = pickle.load(f)
    print(f"✅ Dataset loaded from: {file_path}")
    return dataset

# === File Paths (Updated) ===
train_pickle = r"C:\Users\nidhi\Downloads\Pickle files\Hard Split\One-Hot\A\Train_A.pkl"
test_pickle  = r"C:\Users\nidhi\Downloads\Pickle files\Hard Split\One-Hot\A\Test_A.pkl"

train_dataset = load_pytorch_dataset(train_pickle)
test_dataset = load_pytorch_dataset(test_pickle)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

class SimpleGINModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, drop_out):
        super(SimpleGINModel, self).__init__()
        self.gin1 = GINConv(nn.Linear(input_dim, hidden_dim))
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.gin2 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.gin3 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn3 = nn.BatchNorm1d(hidden_dim)
        self.gin4 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn4 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(drop_out)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.bn1(self.gin1(x, edge_index)))
        x = F.relu(self.bn2(self.gin2(x, edge_index)))
        x = F.relu(self.bn3(self.gin3(x, edge_index)))
        x = F.relu(self.bn4(self.gin4(x, edge_index)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return self.fc(x)

# === Training ===
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct = 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        data.y = data.y.long()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        correct += (out.argmax(dim=1) == data.y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# === Evaluation ===
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss, correct = 0, 0
    all_labels, all_preds, all_probs = [], [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            data.y = data.y.long()
            out = model(data)
            loss = criterion(out, data.y)
            total_loss += loss.item() * data.num_graphs
            correct += (out.argmax(dim=1) == data.y).sum().item()
            probs = F.softmax(out, dim=1)[:, 1].cpu().numpy()
            all_labels.extend(data.y.cpu().numpy())
            all_preds.extend(out.argmax(dim=1).cpu().numpy())
            all_probs.extend(probs)
    return total_loss / len(loader.dataset), correct / len(loader.dataset), \
           np.array(all_labels), np.array(all_preds), np.array(all_probs)

# === Plot Training Metrics ===
def plot_metrics(epochs, train_loss, train_acc, test_loss, test_acc, model_type):
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_loss, color="red")
    plt.plot(epochs, test_loss, color="orange")
    plt.plot(epochs, train_acc, color="green")
    plt.plot(epochs, test_acc, color="blue")
    plt.title(f"Training Metrics ({model_type})", fontsize=14)
    plt.xlabel("Epochs", fontsize=12)
    plt.ylabel("Score", fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"{model_type}_metrics_plot.png")
    plt.close()
    print(f"📈 Training metrics plot saved as {model_type}_metrics_plot.png")

# === Initialize Model ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleGINModel(input_dim=20, hidden_dim=64, output_dim=2, drop_out=0.5).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# === Training Loop ===
num_epochs = 350
train_losses, train_accs, test_losses, test_accs = [], [], [], []
history = []

for epoch in range(1, num_epochs + 1):
    tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
    te_loss, te_acc, y_true, y_pred, y_probs = evaluate(model, test_loader, criterion, device)

    train_losses.append(tr_loss)
    train_accs.append(tr_acc)
    test_losses.append(te_loss)
    test_accs.append(te_acc)
    history.append((y_true, y_pred, y_probs))

    print(f"Epoch {epoch:03d}: Train Loss={tr_loss:.4f}, Train Acc={tr_acc:.4f}, Test Loss={te_loss:.4f}, Test Acc={te_acc:.4f}")

# === Plot Metrics ===
plot_metrics(range(1, num_epochs + 1),
             train_losses, train_accs,
             test_losses, test_accs,
             "A_64OneHOT_NoWD")

# === Save Metrics to Excel ===
excel_data = {
    "Epoch": list(range(1, num_epochs + 1)),
    "Train Accuracy": [round(acc * 100, 2) for acc in train_accs],
    "Train Loss": [round(loss, 2) for loss in train_losses],
    "Test Accuracy": [round(acc * 100, 2) for acc in test_accs],
    "Test Loss": [round(loss, 2) for loss in test_losses],
}

df_metrics = pd.DataFrame(excel_data)
excel_filename = "A_64OneHOT_NoWD.xlsx"

try:
    df_metrics.to_excel(excel_filename, index=False)
    print(f"📊 Epoch-wise metrics saved to '{excel_filename}'")
    print("📂 Saved in:", os.path.abspath(excel_filename))
except Exception as e:
    print("❌ Failed to save Excel file:", str(e))

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.nn import GINConv, global_mean_pool
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score
import pickle
import numpy as np
import random
import os

# === Reproducibility ===
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)

# === Load Pickle Dataset ===
def load_pytorch_dataset(file_path):
    with open(file_path, 'rb') as f:
        dataset = pickle.load(f)
    print(f"✅ Dataset loaded from: {file_path}")
    return dataset

# === File Paths (Update accordingly) ===
train_pickle = r"C:\Users\nidhi\Downloads\Pickle files\Hard Split\One-Hot\A\Train_A.pkl"
test_pickle  = r"C:\Users\nidhi\Downloads\Pickle files\Hard Split\One-Hot\A\Test_A.pkl"

train_dataset = load_pytorch_dataset(train_pickle)
test_dataset = load_pytorch_dataset(test_pickle)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# === Model Definition ===
class SimpleGINModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, drop_out):
        super(SimpleGINModel, self).__init__()
        self.gin1 = GINConv(nn.Linear(input_dim, hidden_dim))
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.gin2 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.gin3 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn3 = nn.BatchNorm1d(hidden_dim)
        self.gin4 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn4 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(drop_out)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.bn1(self.gin1(x, edge_index)))
        x = F.relu(self.bn2(self.gin2(x, edge_index)))
        x = F.relu(self.bn3(self.gin3(x, edge_index)))
        x = F.relu(self.bn4(self.gin4(x, edge_index)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return self.fc(x)

# === Training ===
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct = 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        data.y = data.y.long()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        correct += (out.argmax(dim=1) == data.y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# === Evaluation ===
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss, correct = 0, 0
    y_true, y_pred = [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            data.y = data.y.long()
            out = model(data)
            loss = criterion(out, data.y)
            total_loss += loss.item() * data.num_graphs
            preds = out.argmax(dim=1)
            correct += (preds == data.y).sum().item()
            y_true.extend(data.y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    return total_loss / len(loader.dataset), correct / len(loader.dataset), \
           np.array(y_true), np.array(y_pred)

# === Setup ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleGINModel(input_dim=20, hidden_dim=64, output_dim=2, drop_out=0.5).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# === Train & Save Best Model ===
num_epochs = 350
best_test_loss = float('inf')
best_model_state = None
best_y_true, best_y_pred = None, None
best_epoch = -1

for epoch in range(1, num_epochs + 1):
    tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
    te_loss, te_acc, y_true, y_pred = evaluate(model, test_loader, criterion, device)

    print(f"Epoch {epoch:03d}: Train Loss={tr_loss:.4f}, Train Acc={tr_acc:.4f}, Test Loss={te_loss:.4f}, Test Acc={te_acc:.4f}")

    if te_loss < best_test_loss:
        best_test_loss = te_loss
        best_model_state = model.state_dict()
        best_y_true = y_true
        best_y_pred = y_pred
        best_epoch = epoch

# === Save Model ===
model_path = f"A_64OneHOT_{best_epoch}.pt"
torch.save(best_model_state, model_path)
print(f"\n💾 Best model saved at epoch {best_epoch} with test loss {best_test_loss:.4f}")
print(f"📂 Model saved to: {os.path.abspath(model_path)}")

# === Final Evaluation Metrics ===
precision = precision_score(best_y_true, best_y_pred)
recall = recall_score(best_y_true, best_y_pred)
f1 = f1_score(best_y_true, best_y_pred)
accuracy = np.mean(best_y_true == best_y_pred)

# === Specificity Calculation ===
tn = np.sum((best_y_true == 0) & (best_y_pred == 0))
fp = np.sum((best_y_true == 0) & (best_y_pred == 1))
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

# === Print Metrics ===
print("\n📌 Classification Metrics at Best Test Loss Epoch:")
print(f"✅ Accuracy:    {accuracy:.4f}")
print(f"✅ Precision:   {precision:.4f}")
print(f"✅ Recall:      {recall:.4f}")
print(f"✅ F1 Score:    {f1:.4f}")
print(f"✅ Specificity: {specificity:.4f}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.nn import GINConv, global_mean_pool
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pickle
import numpy as np
import random
import os

# === Reproducibility ===
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)

# === Load Pickle Dataset ===
def load_pytorch_dataset(file_path):
    with open(file_path, 'rb') as f:
        dataset = pickle.load(f)
    print(f"✅ Dataset loaded from: {file_path}")
    return dataset

# === Updated File Paths ===
train_pickle = r"C:\Users\nidhi\Downloads\IICT\Pickle files\Hard Split\One-Hot\A\Train_A.pkl"
test_pickle  = r"C:\Users\nidhi\Downloads\IICT\Pickle files\Hard Split\One-Hot\A\Test_A.pkl"

train_dataset = load_pytorch_dataset(train_pickle)
test_dataset = load_pytorch_dataset(test_pickle)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# === Model Definition ===
class SimpleGINModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, drop_out):
        super(SimpleGINModel, self).__init__()
        self.gin1 = GINConv(nn.Linear(input_dim, hidden_dim))
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.gin2 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.gin3 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn3 = nn.BatchNorm1d(hidden_dim)
        self.gin4 = GINConv(nn.Linear(hidden_dim, hidden_dim))
        self.bn4 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(drop_out)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.bn1(self.gin1(x, edge_index)))
        x = F.relu(self.bn2(self.gin2(x, edge_index)))
        x = F.relu(self.bn3(self.gin3(x, edge_index)))
        x = F.relu(self.bn4(self.gin4(x, edge_index)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return self.fc(x)

# === Training Function ===
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct = 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        data.y = data.y.long()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        correct += (out.argmax(dim=1) == data.y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# === Evaluation Function ===
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss, correct = 0, 0
    y_true, y_pred = [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            data.y = data.y.long()
            out = model(data)
            loss = criterion(out, data.y)
            total_loss += loss.item() * data.num_graphs
            preds = out.argmax(dim=1)
            correct += (preds == data.y).sum().item()
            y_true.extend(data.y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    return total_loss / len(loader.dataset), correct / len(loader.dataset), \
           np.array(y_true), np.array(y_pred)

# === Setup ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleGINModel(input_dim=20, hidden_dim=64, output_dim=2, drop_out=0.5).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# === Training Loop ===
num_epochs = 350
best_test_loss = float('inf')
best_model_state = None
best_y_true, best_y_pred = None, None
best_epoch = -1

for epoch in range(1, num_epochs + 1):
    tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
    te_loss, te_acc, y_true, y_pred = evaluate(model, test_loader, criterion, device)

    print(f"Epoch {epoch:03d}: Train Loss={tr_loss:.4f}, Train Acc={tr_acc:.4f}, Test Loss={te_loss:.4f}, Test Acc={te_acc:.4f}")

    if te_loss < best_test_loss:
        best_test_loss = te_loss
        best_model_state = model.state_dict()
        best_y_true = y_true
        best_y_pred = y_pred
        best_epoch = epoch

# === Save Best Model ===
model_path = f"A+B+C_64OneHOT_{best_epoch}.pt"
torch.save(best_model_state, model_path)
print(f"\n💾 Best model saved at epoch {best_epoch} with test loss {best_test_loss:.4f}")
print(f"📂 Model saved to: {os.path.abspath(model_path)}")

# === Final Evaluation Metrics ===
precision = precision_score(best_y_true, best_y_pred)
recall = recall_score(best_y_true, best_y_pred)
f1 = f1_score(best_y_true, best_y_pred)
accuracy = np.mean(best_y_true == best_y_pred)

# === Specificity Calculation ===
tn = np.sum((best_y_true == 0) & (best_y_pred == 0))
fp = np.sum((best_y_true == 0) & (best_y_pred == 1))
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

# === Print Metrics ===
print("\n📌 Classification Metrics at Best Test Loss Epoch:")
print(f"✅ Accuracy:    {accuracy:.4f}")
print(f"✅ Precision:   {precision:.4f}")
print(f"✅ Recall:      {recall:.4f}")
print(f"✅ F1 Score:    {f1:.4f}")
print(f"✅ Specificity: {specificity:.4f}")

# === Confusion Matrix ===
conf_matrix = confusion_matrix(best_y_true, best_y_pred)
print("\n📊 Confusion Matrix:")
print(conf_matrix)

# === Plot and Save Confusion Matrix ===
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Class 0", "Class 1"])
disp.plot(cmap='Blues', values_format='d')
plt.tight_layout()

# === Save Confusion Matrix Plot ===
conf_matrix_path = f"Confusion_Matrix_A+B+C_{best_epoch}.png"
plt.savefig(conf_matrix_path)
plt.show()
print(f"🖼️ Confusion matrix plot saved to: {os.path.abspath(conf_matrix_path)}")
# Out:
# ✅ Dataset loaded from: C:\Users\nidhi\Downloads\IICT\Pickle files\Hard Split\One-Hot\A\Train_A.pkl
# ✅ Dataset loaded from: C:\Users\nidhi\Downloads\IICT\Pickle files\Hard Split\One-Hot\A\Test_A.pkl
# Epoch 001: Train Loss=0.6963, Train Acc=0.5316, Test Loss=0.6888, Test Acc=0.5644
# Epoch 002: Train Loss=0.6707, Train Acc=0.6271, Test Loss=0.6564, Test Acc=0.7117
# Epoch 003: Train Loss=0.6515, Train Acc=0.6903, Test Loss=0.6453, Test Acc=0.6933
# Epoch 004: Train Loss=0.6311, Train Acc=0.7427, Test Loss=0.6366, Test Acc=0.6933
# Epoch 005: Train Loss=0.6116, Train Acc=0.7735, Test Loss=0.6247, Test Acc=0.7301
# Epoch 006: Train Loss=0.5962, Train Acc=0.7750, Test Loss=0.6144, Test Acc=0.7362
# Epoch 007: Train Loss=0.5813, Train Acc=0.7827, Test Loss=0.6004, Test Acc=0.7301
# Epoch 008: Train Loss=0.5671, Train Acc=0.7874, Test Loss=0.5904, Test Acc=0.7301
# Epoch 009: Train Loss=0.5544, Train Acc=0.7858, Test Loss=0.5819, Test Acc=0.7301
# Epoch 010: Train Loss=0.5441, Train Acc=0.7858, Test Loss=0.5760, Test Acc=0.7301
# Epoch 011: Train Loss=0.5304, Train Acc=0.7935, Test Loss=0.5690, Test Acc=0.7301
# Epoch 012: Train Loss=0.5190, Train Acc=0.7951, Test Loss=0.5638, Test Acc=0.7239
# Epoch 013: Train Loss=0.5089, Train Acc=0.7966, Test Loss=0.5564, Test Acc=0.7301
# Epoch 014: Train Loss=0.5021, Train Acc=0.7920, Test Loss=0.5505, Test Acc=0.7423
# Epoch 015: Train Loss=0.4951, Train Acc=0.7966, Test Loss=0.5487, Test Acc=0.7178
# Epoch 016: Train Loss=0.4878, Train Acc=0.7904, Test Loss=0.5419, Test Acc=0.7423
# Epoch 017: Train Loss=0.4799, Train Acc=0.7951, Test Loss=0.5429, Test Acc=0.7178
# Epoch 018: Train Loss=0.4706, Train Acc=0.7982, Test Loss=0.5339, Test Acc=0.7423
# Epoch 019: Train Loss=0.4646, Train Acc=0.8012, Test Loss=0.5341, Test Acc=0.7301
# Epoch 020: Train Loss=0.4633, Train Acc=0.7997, Test Loss=0.5326, Test Acc=0.7117
# Epoch 021: Train Loss=0.4508, Train Acc=0.8059, Test Loss=0.5294, Test Acc=0.7301
# Epoch 022: Train Loss=0.4493, Train Acc=0.7982, Test Loss=0.5289, Test Acc=0.7178
# Epoch 023: Train Loss=0.4420, Train Acc=0.8043, Test Loss=0.5355, Test Acc=0.7055
# Epoch 024: Train Loss=0.4357, Train Acc=0.8074, Test Loss=0.5332, Test Acc=0.7055
# Epoch 025: Train Loss=0.4282, Train Acc=0.8120, Test Loss=0.5241, Test Acc=0.7178
# Epoch 026: Train Loss=0.4286, Train Acc=0.8151, Test Loss=0.5166, Test Acc=0.7362
# Epoch 027: Train Loss=0.4211, Train Acc=0.8182, Test Loss=0.5187, Test Acc=0.7178
# Epoch 028: Train Loss=0.4134, Train Acc=0.8290, Test Loss=0.5274, Test Acc=0.7239
# Epoch 029: Train Loss=0.4109, Train Acc=0.8351, Test Loss=0.5329, Test Acc=0.7239
# Epoch 030: Train Loss=0.4074, Train Acc=0.8305, Test Loss=0.5334, Test Acc=0.7239
# Epoch 031: Train Loss=0.4016, Train Acc=0.8290, Test Loss=0.5244, Test Acc=0.7178
# Epoch 032: Train Loss=0.3947, Train Acc=0.8320, Test Loss=0.5225, Test Acc=0.7178
# Epoch 033: Train Loss=0.3938, Train Acc=0.8351, Test Loss=0.5220, Test Acc=0.7117
# Epoch 034: Train Loss=0.3900, Train Acc=0.8459, Test Loss=0.5125, Test Acc=0.7239
# Epoch 035: Train Loss=0.3868, Train Acc=0.8521, Test Loss=0.5133, Test Acc=0.7239
# Epoch 036: Train Loss=0.3841, Train Acc=0.8521, Test Loss=0.5079, Test Acc=0.7423
# Epoch 037: Train Loss=0.3769, Train Acc=0.8490, Test Loss=0.5102, Test Acc=0.7362
# Epoch 038: Train Loss=0.3784, Train Acc=0.8582, Test Loss=0.5153, Test Acc=0.7423
# Epoch 039: Train Loss=0.3722, Train Acc=0.8567, Test Loss=0.5101, Test Acc=0.7362
# Epoch 040: Train Loss=0.3669, Train Acc=0.8567, Test Loss=0.5163, Test Acc=0.7485
# Epoch 041: Train Loss=0.3655, Train Acc=0.8659, Test Loss=0.5125, Test Acc=0.7423
# Epoch 042: Train Loss=0.3596, Train Acc=0.8629, Test Loss=0.5247, Test Acc=0.7607
# Epoch 043: Train Loss=0.3564, Train Acc=0.8613, Test Loss=0.5181, Test Acc=0.7546
# Epoch 044: Train Loss=0.3530, Train Acc=0.8644, Test Loss=0.5180, Test Acc=0.7546
# Epoch 045: Train Loss=0.3535, Train Acc=0.8629, Test Loss=0.5046, Test Acc=0.7485
# Epoch 046: Train Loss=0.3425, Train Acc=0.8737, Test Loss=0.5068, Test Acc=0.7485
# Epoch 047: Train Loss=0.3432, Train Acc=0.8690, Test Loss=0.5242, Test Acc=0.7669
# Epoch 048: Train Loss=0.3370, Train Acc=0.8675, Test Loss=0.5174, Test Acc=0.7669
# Epoch 049: Train Loss=0.3377, Train Acc=0.8598, Test Loss=0.5113, Test Acc=0.7607
# Epoch 050: Train Loss=0.3296, Train Acc=0.8737, Test Loss=0.5210, Test Acc=0.7669
# Epoch 051: Train Loss=0.3265, Train Acc=0.8767, Test Loss=0.5071, Test Acc=0.7669
# Epoch 052: Train Loss=0.3241, Train Acc=0.8814, Test Loss=0.5095, Test Acc=0.7669
# Epoch 053: Train Loss=0.3180, Train Acc=0.8783, Test Loss=0.5117, Test Acc=0.7669
# Epoch 054: Train Loss=0.3187, Train Acc=0.8767, Test Loss=0.5097, Test Acc=0.7607
# Epoch 055: Train Loss=0.3108, Train Acc=0.8860, Test Loss=0.5079, Test Acc=0.7730
# Epoch 056: Train Loss=0.3186, Train Acc=0.8875, Test Loss=0.5049, Test Acc=0.7730
# Epoch 057: Train Loss=0.3109, Train Acc=0.8783, Test Loss=0.5058, Test Acc=0.7730
# Epoch 058: Train Loss=0.3089, Train Acc=0.8767, Test Loss=0.5010, Test Acc=0.7669
# Epoch 059: Train Loss=0.3028, Train Acc=0.8844, Test Loss=0.5143, Test Acc=0.7791
# Epoch 060: Train Loss=0.3031, Train Acc=0.8829, Test Loss=0.5176, Test Acc=0.7607
# Epoch 061: Train Loss=0.2952, Train Acc=0.8891, Test Loss=0.5355, Test Acc=0.7607
# Epoch 062: Train Loss=0.2932, Train Acc=0.8906, Test Loss=0.5038, Test Acc=0.7607
# Epoch 063: Train Loss=0.2919, Train Acc=0.8921, Test Loss=0.4977, Test Acc=0.7791
# Epoch 064: Train Loss=0.2868, Train Acc=0.8891, Test Loss=0.4875, Test Acc=0.7791
# Epoch 065: Train Loss=0.2871, Train Acc=0.8937, Test Loss=0.4841, Test Acc=0.7730
# Epoch 066: Train Loss=0.2761, Train Acc=0.8998, Test Loss=0.5022, Test Acc=0.7546
# Epoch 067: Train Loss=0.2730, Train Acc=0.9029, Test Loss=0.5025, Test Acc=0.7607
# Epoch 068: Train Loss=0.2718, Train Acc=0.9014, Test Loss=0.4876, Test Acc=0.7669
# Epoch 069: Train Loss=0.2709, Train Acc=0.9014, Test Loss=0.4828, Test Acc=0.7669
# Epoch 070: Train Loss=0.2682, Train Acc=0.9106, Test Loss=0.4860, Test Acc=0.7730
# Epoch 071: Train Loss=0.2628, Train Acc=0.8952, Test Loss=0.4979, Test Acc=0.7853
# Epoch 072: Train Loss=0.2628, Train Acc=0.9060, Test Loss=0.5173, Test Acc=0.7669
# Epoch 073: Train Loss=0.2555, Train Acc=0.9091, Test Loss=0.4932, Test Acc=0.7853
# Epoch 074: Train Loss=0.2525, Train Acc=0.9106, Test Loss=0.4811, Test Acc=0.7791
# Epoch 075: Train Loss=0.2520, Train Acc=0.9153, Test Loss=0.4724, Test Acc=0.7975
# Epoch 076: Train Loss=0.2490, Train Acc=0.9183, Test Loss=0.4761, Test Acc=0.7914
# Epoch 077: Train Loss=0.2487, Train Acc=0.9106, Test Loss=0.4866, Test Acc=0.7914
# Epoch 078: Train Loss=0.2455, Train Acc=0.9122, Test Loss=0.4774, Test Acc=0.8037
# Epoch 079: Train Loss=0.2416, Train Acc=0.9230, Test Loss=0.4818, Test Acc=0.7975
# Epoch 080: Train Loss=0.2381, Train Acc=0.9168, Test Loss=0.4634, Test Acc=0.8037
# Epoch 081: Train Loss=0.2363, Train Acc=0.9260, Test Loss=0.4726, Test Acc=0.8098
# Epoch 082: Train Loss=0.2311, Train Acc=0.9199, Test Loss=0.4789, Test Acc=0.8098
# Epoch 083: Train Loss=0.2261, Train Acc=0.9307, Test Loss=0.4610, Test Acc=0.7914
# Epoch 084: Train Loss=0.2247, Train Acc=0.9276, Test Loss=0.4891, Test Acc=0.7853
# Epoch 085: Train Loss=0.2199, Train Acc=0.9291, Test Loss=0.5145, Test Acc=0.7546
# Epoch 086: Train Loss=0.2195, Train Acc=0.9353, Test Loss=0.4717, Test Acc=0.7975
# Epoch 087: Train Loss=0.2170, Train Acc=0.9353, Test Loss=0.4869, Test Acc=0.7791
# Epoch 088: Train Loss=0.2158, Train Acc=0.9368, Test Loss=0.4892, Test Acc=0.7853
# Epoch 089: Train Loss=0.2107, Train Acc=0.9353, Test Loss=0.4797, Test Acc=0.7914
# Epoch 090: Train Loss=0.2147, Train Acc=0.9384, Test Loss=0.4697, Test Acc=0.8098
# Epoch 091: Train Loss=0.2109, Train Acc=0.9368, Test Loss=0.4782, Test Acc=0.8037
# Epoch 092: Train Loss=0.2135, Train Acc=0.9260, Test Loss=0.4842, Test Acc=0.7914
# Epoch 093: Train Loss=0.2024, Train Acc=0.9445, Test Loss=0.4640, Test Acc=0.8037
# Epoch 094: Train Loss=0.2089, Train Acc=0.9322, Test Loss=0.4806, Test Acc=0.7975
# Epoch 095: Train Loss=0.1987, Train Acc=0.9368, Test Loss=0.4592, Test Acc=0.8098
# Epoch 096: Train Loss=0.1993, Train Acc=0.9461, Test Loss=0.4601, Test Acc=0.8098
# Epoch 097: Train Loss=0.1987, Train Acc=0.9476, Test Loss=0.4590, Test Acc=0.8037
# Epoch 098: Train Loss=0.1915, Train Acc=0.9492, Test Loss=0.4726, Test Acc=0.8037
# Epoch 099: Train Loss=0.1851, Train Acc=0.9507, Test Loss=0.4864, Test Acc=0.7791
# Epoch 100: Train Loss=0.1848, Train Acc=0.9507, Test Loss=0.4437, Test Acc=0.8282
# Epoch 101: Train Loss=0.1870, Train Acc=0.9461, Test Loss=0.4465, Test Acc=0.8344
# Epoch 102: Train Loss=0.1777, Train Acc=0.9553, Test Loss=0.4595, Test Acc=0.7975
# Epoch 103: Train Loss=0.1796, Train Acc=0.9522, Test Loss=0.4677, Test Acc=0.7975
# Epoch 104: Train Loss=0.1764, Train Acc=0.9553, Test Loss=0.4579, Test Acc=0.8098
# Epoch 105: Train Loss=0.1797, Train Acc=0.9492, Test Loss=0.4653, Test Acc=0.8037
# Epoch 106: Train Loss=0.1762, Train Acc=0.9615, Test Loss=0.4589, Test Acc=0.8160
# Epoch 107: Train Loss=0.1792, Train Acc=0.9507, Test Loss=0.4492, Test Acc=0.8221
# Epoch 108: Train Loss=0.1702, Train Acc=0.9584, Test Loss=0.4416, Test Acc=0.8405
# Epoch 109: Train Loss=0.1628, Train Acc=0.9584, Test Loss=0.4410, Test Acc=0.8650
# Epoch 110: Train Loss=0.1662, Train Acc=0.9553, Test Loss=0.4364, Test Acc=0.8528
# Epoch 111: Train Loss=0.1645, Train Acc=0.9599, Test Loss=0.4372, Test Acc=0.8344
# Epoch 112: Train Loss=0.1581, Train Acc=0.9615, Test Loss=0.4445, Test Acc=0.8528
# Epoch 113: Train Loss=0.1529, Train Acc=0.9692, Test Loss=0.4396, Test Acc=0.8466
# Epoch 114: Train Loss=0.1577, Train Acc=0.9553, Test Loss=0.4365, Test Acc=0.8282
# Epoch 115: Train Loss=0.1558, Train Acc=0.9615, Test Loss=0.4601, Test Acc=0.8282
# Epoch 116: Train Loss=0.1537, Train Acc=0.9661, Test Loss=0.4655, Test Acc=0.8405
# Epoch 117: Train Loss=0.1556, Train Acc=0.9599, Test Loss=0.4317, Test Acc=0.8589
# Epoch 118: Train Loss=0.1479, Train Acc=0.9676, Test Loss=0.4388, Test Acc=0.8344
# Epoch 119: Train Loss=0.1494, Train Acc=0.9584, Test Loss=0.4261, Test Acc=0.8896
# Epoch 120: Train Loss=0.1425, Train Acc=0.9707, Test Loss=0.4462, Test Acc=0.8466
# Epoch 121: Train Loss=0.1423, Train Acc=0.9661, Test Loss=0.4570, Test Acc=0.8344
# Epoch 122: Train Loss=0.1426, Train Acc=0.9615, Test Loss=0.4520, Test Acc=0.8344
# Epoch 123: Train Loss=0.1396, Train Acc=0.9676, Test Loss=0.4382, Test Acc=0.8528
# Epoch 124: Train Loss=0.1509, Train Acc=0.9723, Test Loss=0.4592, Test Acc=0.8221
# Epoch 125: Train Loss=0.1296, Train Acc=0.9784, Test Loss=0.4360, Test Acc=0.8528
# Epoch 126: Train Loss=0.1395, Train Acc=0.9692, Test Loss=0.4348, Test Acc=0.8589
# Epoch 127: Train Loss=0.1369, Train Acc=0.9676, Test Loss=0.4377, Test Acc=0.8466
# Epoch 128: Train Loss=0.1348, Train Acc=0.9707, Test Loss=0.4283, Test Acc=0.8712
# Epoch 129: Train Loss=0.1249, Train Acc=0.9815, Test Loss=0.4249, Test Acc=0.8712
# Epoch 130: Train Loss=0.1252, Train Acc=0.9769, Test Loss=0.4556, Test Acc=0.8221
# Epoch 131: Train Loss=0.1262, Train Acc=0.9769, Test Loss=0.4455, Test Acc=0.8221
# Epoch 132: Train Loss=0.1244, Train Acc=0.9815, Test Loss=0.5079, Test Acc=0.7791
# Epoch 133: Train Loss=0.1245, Train Acc=0.9800, Test Loss=0.4566, Test Acc=0.8282
# Epoch 134: Train Loss=0.1230, Train Acc=0.9738, Test Loss=0.4182, Test Acc=0.8712
# Epoch 135: Train Loss=0.1218, Train Acc=0.9738, Test Loss=0.4429, Test Acc=0.8282
# Epoch 136: Train Loss=0.1192, Train Acc=0.9784, Test Loss=0.4391, Test Acc=0.8405
# Epoch 137: Train Loss=0.1249, Train Acc=0.9800, Test Loss=0.4069, Test Acc=0.8773
# Epoch 138: Train Loss=0.1105, Train Acc=0.9846, Test Loss=0.4348, Test Acc=0.8466
# Epoch 139: Train Loss=0.1108, Train Acc=0.9831, Test Loss=0.4288, Test Acc=0.8589
# Epoch 140: Train Loss=0.1091, Train Acc=0.9846, Test Loss=0.4226, Test Acc=0.8773
# Epoch 141: Train Loss=0.1111, Train Acc=0.9831, Test Loss=0.4142, Test Acc=0.8834
# Epoch 142: Train Loss=0.1034, Train Acc=0.9908, Test Loss=0.4110, Test Acc=0.8834
# Epoch 143: Train Loss=0.1126, Train Acc=0.9784, Test Loss=0.4806, Test Acc=0.8098
# Epoch 144: Train Loss=0.1028, Train Acc=0.9861, Test Loss=0.4665, Test Acc=0.8098
# Epoch 145: Train Loss=0.1040, Train Acc=0.9846, Test Loss=0.4195, Test Acc=0.8712
# Epoch 146: Train Loss=0.1003, Train Acc=0.9861, Test Loss=0.4299, Test Acc=0.8528
# Epoch 147: Train Loss=0.1082, Train Acc=0.9861, Test Loss=0.4156, Test Acc=0.8773
# Epoch 148: Train Loss=0.1018, Train Acc=0.9908, Test Loss=0.4203, Test Acc=0.8712
# Epoch 149: Train Loss=0.0987, Train Acc=0.9877, Test Loss=0.4434, Test Acc=0.8221
# Epoch 150: Train Loss=0.0942, Train Acc=0.9908, Test Loss=0.4143, Test Acc=0.8896
# Epoch 151: Train Loss=0.0935, Train Acc=0.9861, Test Loss=0.4270, Test Acc=0.8650
# Epoch 152: Train Loss=0.0939, Train Acc=0.9892, Test Loss=0.4125, Test Acc=0.8773
# Epoch 153: Train Loss=0.0968, Train Acc=0.9877, Test Loss=0.4173, Test Acc=0.8834
# Epoch 154: Train Loss=0.0915, Train Acc=0.9892, Test Loss=0.4376, Test Acc=0.8589
# Epoch 155: Train Loss=0.0913, Train Acc=0.9892, Test Loss=0.4544, Test Acc=0.8160
# Epoch 156: Train Loss=0.0909, Train Acc=0.9877, Test Loss=0.4664, Test Acc=0.8098
# Epoch 157: Train Loss=0.0878, Train Acc=0.9892, Test Loss=0.4529, Test Acc=0.8405
# Epoch 158: Train Loss=0.0877, Train Acc=0.9908, Test Loss=0.4042, Test Acc=0.8896
# Epoch 159: Train Loss=0.0890, Train Acc=0.9861, Test Loss=0.4687, Test Acc=0.8098
# Epoch 160: Train Loss=0.0837, Train Acc=0.9908, Test Loss=0.4525, Test Acc=0.8160
# Epoch 161: Train Loss=0.0806, Train Acc=0.9938, Test Loss=0.4554, Test Acc=0.8221
# Epoch 162: Train Loss=0.0799, Train Acc=0.9923, Test Loss=0.4110, Test Acc=0.8834
# Epoch 163: Train Loss=0.0779, Train Acc=0.9923, Test Loss=0.4298, Test Acc=0.8650
# Epoch 164: Train Loss=0.0782, Train Acc=0.9954, Test Loss=0.4136, Test Acc=0.8650
# Epoch 165: Train Loss=0.0786, Train Acc=0.9938, Test Loss=0.4277, Test Acc=0.8528
# Epoch 166: Train Loss=0.0777, Train Acc=0.9954, Test Loss=0.4146, Test Acc=0.8712
# Epoch 167: Train Loss=0.0789, Train Acc=0.9923, Test Loss=0.4296, Test Acc=0.8405
# Epoch 168: Train Loss=0.0740, Train Acc=0.9923, Test Loss=0.4231, Test Acc=0.8650
# Epoch 169: Train Loss=0.0766, Train Acc=0.9969, Test Loss=0.4266, Test Acc=0.8712
# Epoch 170: Train Loss=0.0810, Train Acc=0.9892, Test Loss=0.4300, Test Acc=0.8589
# Epoch 171: Train Loss=0.0717, Train Acc=0.9954, Test Loss=0.4264, Test Acc=0.8650
# Epoch 172: Train Loss=0.0771, Train Acc=0.9908, Test Loss=0.4308, Test Acc=0.8773
# Epoch 173: Train Loss=0.0743, Train Acc=0.9938, Test Loss=0.4670, Test Acc=0.8160
# Epoch 174: Train Loss=0.0741, Train Acc=0.9954, Test Loss=0.4301, Test Acc=0.8528
# Epoch 175: Train Loss=0.0665, Train Acc=0.9969, Test Loss=0.4248, Test Acc=0.8896
# Epoch 176: Train Loss=0.0715, Train Acc=0.9969, Test Loss=0.4196, Test Acc=0.8834
# Epoch 177: Train Loss=0.0682, Train Acc=0.9923, Test Loss=0.4376, Test Acc=0.8650
# Epoch 178: Train Loss=0.0653, Train Acc=0.9954, Test Loss=0.4135, Test Acc=0.8896
# Epoch 179: Train Loss=0.0671, Train Acc=0.9938, Test Loss=0.4109, Test Acc=0.8896
# Epoch 180: Train Loss=0.0675, Train Acc=0.9923, Test Loss=0.4120, Test Acc=0.8773
# Epoch 181: Train Loss=0.0666, Train Acc=0.9954, Test Loss=0.4464, Test Acc=0.8466
# Epoch 182: Train Loss=0.0656, Train Acc=0.9923, Test Loss=0.4073, Test Acc=0.8896
# Epoch 183: Train Loss=0.0646, Train Acc=0.9908, Test Loss=0.4181, Test Acc=0.8834
# Epoch 184: Train Loss=0.0650, Train Acc=0.9938, Test Loss=0.4668, Test Acc=0.8221
# Epoch 185: Train Loss=0.0656, Train Acc=0.9954, Test Loss=0.4450, Test Acc=0.8282
# Epoch 186: Train Loss=0.0623, Train Acc=0.9923, Test Loss=0.4276, Test Acc=0.8650
# Epoch 187: Train Loss=0.0624, Train Acc=0.9908, Test Loss=0.4249, Test Acc=0.8650
# Epoch 188: Train Loss=0.0604, Train Acc=0.9969, Test Loss=0.4055, Test Acc=0.8834
# Epoch 189: Train Loss=0.0621, Train Acc=0.9938, Test Loss=0.4303, Test Acc=0.8405
# Epoch 190: Train Loss=0.0627, Train Acc=0.9969, Test Loss=0.4040, Test Acc=0.9018
# Epoch 191: Train Loss=0.0606, Train Acc=0.9969, Test Loss=0.4273, Test Acc=0.8344
# Epoch 192: Train Loss=0.0555, Train Acc=0.9985, Test Loss=0.4584, Test Acc=0.8344
# Epoch 193: Train Loss=0.0569, Train Acc=0.9969, Test Loss=0.4282, Test Acc=0.8589
# Epoch 194: Train Loss=0.0518, Train Acc=0.9954, Test Loss=0.4358, Test Acc=0.8405
# Epoch 195: Train Loss=0.0536, Train Acc=0.9969, Test Loss=0.4148, Test Acc=0.8896
# Epoch 196: Train Loss=0.0521, Train Acc=0.9969, Test Loss=0.4258, Test Acc=0.8712
# Epoch 197: Train Loss=0.0507, Train Acc=0.9985, Test Loss=0.4605, Test Acc=0.8344
# Epoch 198: Train Loss=0.0482, Train Acc=0.9969, Test Loss=0.4279, Test Acc=0.8466
# Epoch 199: Train Loss=0.0509, Train Acc=0.9985, Test Loss=0.4199, Test Acc=0.8466
# Epoch 200: Train Loss=0.0518, Train Acc=0.9954, Test Loss=0.5162, Test Acc=0.7853
# Epoch 201: Train Loss=0.0614, Train Acc=0.9923, Test Loss=0.4494, Test Acc=0.8528
# Epoch 202: Train Loss=0.0498, Train Acc=0.9969, Test Loss=0.4129, Test Acc=0.8773
# Epoch 203: Train Loss=0.0531, Train Acc=0.9985, Test Loss=0.3982, Test Acc=0.9080
# Epoch 204: Train Loss=0.0517, Train Acc=1.0000, Test Loss=0.4447, Test Acc=0.8344
# Epoch 205: Train Loss=0.0448, Train Acc=0.9985, Test Loss=0.4782, Test Acc=0.8282
# Epoch 206: Train Loss=0.0466, Train Acc=0.9969, Test Loss=0.4551, Test Acc=0.8344
# Epoch 207: Train Loss=0.0462, Train Acc=0.9969, Test Loss=0.4396, Test Acc=0.8773
# Epoch 208: Train Loss=0.0426, Train Acc=1.0000, Test Loss=0.4080, Test Acc=0.9018
# Epoch 209: Train Loss=0.0468, Train Acc=0.9985, Test Loss=0.4644, Test Acc=0.8221
# Epoch 210: Train Loss=0.0459, Train Acc=0.9985, Test Loss=0.4719, Test Acc=0.8344
# Epoch 211: Train Loss=0.0513, Train Acc=0.9908, Test Loss=0.5684, Test Acc=0.7607
# Epoch 212: Train Loss=0.0500, Train Acc=0.9938, Test Loss=0.4343, Test Acc=0.8773
# Epoch 213: Train Loss=0.0456, Train Acc=0.9969, Test Loss=0.4475, Test Acc=0.8589
# Epoch 214: Train Loss=0.0499, Train Acc=0.9969, Test Loss=0.4139, Test Acc=0.8773
# Epoch 215: Train Loss=0.0463, Train Acc=0.9969, Test Loss=0.4082, Test Acc=0.8712
# Epoch 216: Train Loss=0.0453, Train Acc=0.9954, Test Loss=0.5295, Test Acc=0.7791
# Epoch 217: Train Loss=0.0439, Train Acc=0.9985, Test Loss=0.4315, Test Acc=0.8957
# Epoch 218: Train Loss=0.0437, Train Acc=0.9985, Test Loss=0.4067, Test Acc=0.9018
# Epoch 219: Train Loss=0.0403, Train Acc=1.0000, Test Loss=0.4415, Test Acc=0.8466
# Epoch 220: Train Loss=0.0378, Train Acc=1.0000, Test Loss=0.4865, Test Acc=0.8221
# Epoch 221: Train Loss=0.0385, Train Acc=0.9969, Test Loss=0.4449, Test Acc=0.8712
# Epoch 222: Train Loss=0.0463, Train Acc=0.9954, Test Loss=0.4438, Test Acc=0.8712
# Epoch 223: Train Loss=0.0477, Train Acc=0.9969, Test Loss=0.4540, Test Acc=0.8712
# Epoch 224: Train Loss=0.0412, Train Acc=1.0000, Test Loss=0.4094, Test Acc=0.8896
# Epoch 225: Train Loss=0.0402, Train Acc=0.9985, Test Loss=0.4538, Test Acc=0.8344
# Epoch 226: Train Loss=0.0386, Train Acc=1.0000, Test Loss=0.4483, Test Acc=0.8589
# Epoch 227: Train Loss=0.0399, Train Acc=0.9954, Test Loss=0.4176, Test Acc=0.9080
# Epoch 228: Train Loss=0.0363, Train Acc=1.0000, Test Loss=0.4186, Test Acc=0.8712
# Epoch 229: Train Loss=0.0384, Train Acc=0.9985, Test Loss=0.4453, Test Acc=0.8528
# Epoch 230: Train Loss=0.0398, Train Acc=0.9985, Test Loss=0.4037, Test Acc=0.8957
# Epoch 231: Train Loss=0.0424, Train Acc=0.9985, Test Loss=0.5398, Test Acc=0.7914
# Epoch 232: Train Loss=0.0364, Train Acc=0.9969, Test Loss=0.5301, Test Acc=0.7853
# Epoch 233: Train Loss=0.0330, Train Acc=0.9985, Test Loss=0.4238, Test Acc=0.8957
# Epoch 234: Train Loss=0.0341, Train Acc=0.9985, Test Loss=0.4215, Test Acc=0.9080
# Epoch 235: Train Loss=0.0311, Train Acc=1.0000, Test Loss=0.5036, Test Acc=0.8282
# Epoch 236: Train Loss=0.0331, Train Acc=0.9969, Test Loss=0.4294, Test Acc=0.8957
# Epoch 237: Train Loss=0.0317, Train Acc=1.0000, Test Loss=0.4207, Test Acc=0.8896
# Epoch 238: Train Loss=0.0364, Train Acc=1.0000, Test Loss=0.4568, Test Acc=0.8650
# Epoch 239: Train Loss=0.0330, Train Acc=1.0000, Test Loss=0.4510, Test Acc=0.8650
# Epoch 240: Train Loss=0.0346, Train Acc=1.0000, Test Loss=0.4274, Test Acc=0.8957
# Epoch 241: Train Loss=0.0299, Train Acc=1.0000, Test Loss=0.4303, Test Acc=0.8712
# Epoch 242: Train Loss=0.0353, Train Acc=0.9985, Test Loss=0.4387, Test Acc=0.8712
# Epoch 243: Train Loss=0.0291, Train Acc=1.0000, Test Loss=0.4841, Test Acc=0.8282
# Epoch 244: Train Loss=0.0322, Train Acc=1.0000, Test Loss=0.4579, Test Acc=0.8344
# Epoch 245: Train Loss=0.0330, Train Acc=1.0000, Test Loss=0.4173, Test Acc=0.8957
# Epoch 246: Train Loss=0.0351, Train Acc=1.0000, Test Loss=0.4523, Test Acc=0.8773
# Epoch 247: Train Loss=0.0296, Train Acc=1.0000, Test Loss=0.4629, Test Acc=0.8405
# Epoch 248: Train Loss=0.0316, Train Acc=0.9985, Test Loss=0.4402, Test Acc=0.8773
# Epoch 249: Train Loss=0.0265, Train Acc=1.0000, Test Loss=0.4489, Test Acc=0.8466
# Epoch 250: Train Loss=0.0293, Train Acc=1.0000, Test Loss=0.4792, Test Acc=0.8712
# Epoch 251: Train Loss=0.0288, Train Acc=1.0000, Test Loss=0.4532, Test Acc=0.8466
# Epoch 252: Train Loss=0.0281, Train Acc=1.0000, Test Loss=0.4528, Test Acc=0.8650
# Epoch 253: Train Loss=0.0257, Train Acc=1.0000, Test Loss=0.4464, Test Acc=0.8896
# Epoch 254: Train Loss=0.0335, Train Acc=0.9985, Test Loss=0.4473, Test Acc=0.8773
# Epoch 255: Train Loss=0.0293, Train Acc=1.0000, Test Loss=0.4434, Test Acc=0.8528
# Epoch 256: Train Loss=0.0308, Train Acc=0.9985, Test Loss=0.4486, Test Acc=0.8589
# Epoch 257: Train Loss=0.0270, Train Acc=1.0000, Test Loss=0.4132, Test Acc=0.9080
# Epoch 258: Train Loss=0.0274, Train Acc=1.0000, Test Loss=0.4675, Test Acc=0.8221
# Epoch 259: Train Loss=0.0252, Train Acc=1.0000, Test Loss=0.4926, Test Acc=0.8160
# Epoch 260: Train Loss=0.0317, Train Acc=1.0000, Test Loss=0.4375, Test Acc=0.8589
# Epoch 261: Train Loss=0.0261, Train Acc=1.0000, Test Loss=0.4336, Test Acc=0.8466
# Epoch 262: Train Loss=0.0257, Train Acc=1.0000, Test Loss=0.4408, Test Acc=0.8773
# Epoch 263: Train Loss=0.0273, Train Acc=0.9985, Test Loss=0.4274, Test Acc=0.8957
# Epoch 264: Train Loss=0.0321, Train Acc=0.9985, Test Loss=0.4506, Test Acc=0.8528
# Epoch 265: Train Loss=0.0338, Train Acc=0.9969, Test Loss=0.4898, Test Acc=0.8282
# Epoch 266: Train Loss=0.0261, Train Acc=0.9985, Test Loss=0.4309, Test Acc=0.8773
# Epoch 267: Train Loss=0.0269, Train Acc=1.0000, Test Loss=0.4101, Test Acc=0.8957
# Epoch 268: Train Loss=0.0254, Train Acc=1.0000, Test Loss=0.4615, Test Acc=0.8405
# Epoch 269: Train Loss=0.0233, Train Acc=1.0000, Test Loss=0.4564, Test Acc=0.8466
# Epoch 270: Train Loss=0.0231, Train Acc=1.0000, Test Loss=0.4325, Test Acc=0.8834
# Epoch 271: Train Loss=0.0225, Train Acc=1.0000, Test Loss=0.4228, Test Acc=0.8896
# Epoch 272: Train Loss=0.0252, Train Acc=0.9985, Test Loss=0.5110, Test Acc=0.7975
# Epoch 273: Train Loss=0.0229, Train Acc=1.0000, Test Loss=0.5321, Test Acc=0.8160
# Epoch 274: Train Loss=0.0268, Train Acc=0.9969, Test Loss=0.4916, Test Acc=0.8282
# Epoch 275: Train Loss=0.0255, Train Acc=1.0000, Test Loss=0.5162, Test Acc=0.8160
# Epoch 276: Train Loss=0.0270, Train Acc=1.0000, Test Loss=0.4690, Test Acc=0.8528
# Epoch 277: Train Loss=0.0289, Train Acc=0.9985, Test Loss=0.4293, Test Acc=0.9018
# Epoch 278: Train Loss=0.0234, Train Acc=1.0000, Test Loss=0.4357, Test Acc=0.9018
# Epoch 279: Train Loss=0.0230, Train Acc=1.0000, Test Loss=0.4399, Test Acc=0.8957
# Epoch 280: Train Loss=0.0225, Train Acc=1.0000, Test Loss=0.4396, Test Acc=0.8834
# Epoch 281: Train Loss=0.0211, Train Acc=1.0000, Test Loss=0.4497, Test Acc=0.8712
# Epoch 282: Train Loss=0.0257, Train Acc=1.0000, Test Loss=0.4603, Test Acc=0.8589
# Epoch 283: Train Loss=0.0202, Train Acc=1.0000, Test Loss=0.4297, Test Acc=0.8773
# Epoch 284: Train Loss=0.0227, Train Acc=1.0000, Test Loss=0.4356, Test Acc=0.8834
# Epoch 285: Train Loss=0.0219, Train Acc=1.0000, Test Loss=0.4406, Test Acc=0.8712
# Epoch 286: Train Loss=0.0229, Train Acc=1.0000, Test Loss=0.5369, Test Acc=0.7975
# Epoch 287: Train Loss=0.0218, Train Acc=1.0000, Test Loss=0.5224, Test Acc=0.8098
# Epoch 288: Train Loss=0.0203, Train Acc=1.0000, Test Loss=0.4495, Test Acc=0.8773
# Epoch 289: Train Loss=0.0198, Train Acc=1.0000, Test Loss=0.4454, Test Acc=0.8773
# Epoch 290: Train Loss=0.0219, Train Acc=1.0000, Test Loss=0.4550, Test Acc=0.8528
# Epoch 291: Train Loss=0.0173, Train Acc=1.0000, Test Loss=0.4210, Test Acc=0.8834
# Epoch 292: Train Loss=0.0195, Train Acc=1.0000, Test Loss=0.4187, Test Acc=0.8834
# Epoch 293: Train Loss=0.0193, Train Acc=1.0000, Test Loss=0.4331, Test Acc=0.8712
# Epoch 294: Train Loss=0.0184, Train Acc=1.0000, Test Loss=0.4656, Test Acc=0.8466
# Epoch 295: Train Loss=0.0208, Train Acc=1.0000, Test Loss=0.4539, Test Acc=0.8466
# Epoch 296: Train Loss=0.0175, Train Acc=1.0000, Test Loss=0.4384, Test Acc=0.8589
# Epoch 297: Train Loss=0.0176, Train Acc=1.0000, Test Loss=0.4612, Test Acc=0.8528
# Epoch 298: Train Loss=0.0223, Train Acc=1.0000, Test Loss=0.4516, Test Acc=0.8589
# Epoch 299: Train Loss=0.0185, Train Acc=1.0000, Test Loss=0.4296, Test Acc=0.9202
# Epoch 300: Train Loss=0.0189, Train Acc=1.0000, Test Loss=0.4645, Test Acc=0.8528
# Epoch 301: Train Loss=0.0192, Train Acc=1.0000, Test Loss=0.4944, Test Acc=0.8221
# Epoch 302: Train Loss=0.0160, Train Acc=1.0000, Test Loss=0.4625, Test Acc=0.8650
# Epoch 303: Train Loss=0.0174, Train Acc=1.0000, Test Loss=0.4707, Test Acc=0.8528
# Epoch 304: Train Loss=0.0181, Train Acc=1.0000, Test Loss=0.5292, Test Acc=0.8098
# Epoch 305: Train Loss=0.0182, Train Acc=1.0000, Test Loss=0.4640, Test Acc=0.8405
# Epoch 306: Train Loss=0.0182, Train Acc=1.0000, Test Loss=0.4690, Test Acc=0.8405
# Epoch 307: Train Loss=0.0198, Train Acc=0.9985, Test Loss=0.4303, Test Acc=0.8896
# Epoch 308: Train Loss=0.0190, Train Acc=1.0000, Test Loss=0.5187, Test Acc=0.7975
# Epoch 309: Train Loss=0.0177, Train Acc=1.0000, Test Loss=0.5280, Test Acc=0.7914
# Epoch 310: Train Loss=0.0180, Train Acc=1.0000, Test Loss=0.4456, Test Acc=0.8773
# Epoch 311: Train Loss=0.0174, Train Acc=1.0000, Test Loss=0.4349, Test Acc=0.9018
# Epoch 312: Train Loss=0.0159, Train Acc=1.0000, Test Loss=0.4239, Test Acc=0.9141
# Epoch 313: Train Loss=0.0226, Train Acc=1.0000, Test Loss=0.4238, Test Acc=0.8957
# Epoch 314: Train Loss=0.0192, Train Acc=1.0000, Test Loss=0.4284, Test Acc=0.8834
# Epoch 315: Train Loss=0.0148, Train Acc=1.0000, Test Loss=0.4357, Test Acc=0.8957
# Epoch 316: Train Loss=0.0160, Train Acc=1.0000, Test Loss=0.4513, Test Acc=0.8589
# Epoch 317: Train Loss=0.0255, Train Acc=0.9954, Test Loss=0.4506, Test Acc=0.8773
# Epoch 318: Train Loss=0.0232, Train Acc=0.9985, Test Loss=0.4671, Test Acc=0.8834
# Epoch 319: Train Loss=0.0278, Train Acc=0.9969, Test Loss=0.4371, Test Acc=0.8405
# Epoch 320: Train Loss=0.0193, Train Acc=1.0000, Test Loss=0.4279, Test Acc=0.8528
# Epoch 321: Train Loss=0.0168, Train Acc=1.0000, Test Loss=0.4582, Test Acc=0.8405
# Epoch 322: Train Loss=0.0149, Train Acc=1.0000, Test Loss=0.4467, Test Acc=0.8589
# Epoch 323: Train Loss=0.0149, Train Acc=1.0000, Test Loss=0.4675, Test Acc=0.8466
# Epoch 324: Train Loss=0.0148, Train Acc=1.0000, Test Loss=0.4653, Test Acc=0.8650
# Epoch 325: Train Loss=0.0148, Train Acc=1.0000, Test Loss=0.4603, Test Acc=0.8589
# Epoch 326: Train Loss=0.0142, Train Acc=1.0000, Test Loss=0.4545, Test Acc=0.8650
# Epoch 327: Train Loss=0.0135, Train Acc=1.0000, Test Loss=0.4469, Test Acc=0.8712
# Epoch 328: Train Loss=0.0131, Train Acc=1.0000, Test Loss=0.4514, Test Acc=0.8528
# Epoch 329: Train Loss=0.0171, Train Acc=1.0000, Test Loss=0.4438, Test Acc=0.8712
# Epoch 330: Train Loss=0.0120, Train Acc=1.0000, Test Loss=0.4600, Test Acc=0.8405
# Epoch 331: Train Loss=0.0137, Train Acc=1.0000, Test Loss=0.4692, Test Acc=0.8344
# Epoch 332: Train Loss=0.0161, Train Acc=1.0000, Test Loss=0.4483, Test Acc=0.8712
# Epoch 333: Train Loss=0.0144, Train Acc=1.0000, Test Loss=0.4984, Test Acc=0.8221
# Epoch 334: Train Loss=0.0135, Train Acc=1.0000, Test Loss=0.4596, Test Acc=0.8834
# Epoch 335: Train Loss=0.0119, Train Acc=1.0000, Test Loss=0.4491, Test Acc=0.8773
# Epoch 336: Train Loss=0.0128, Train Acc=1.0000, Test Loss=0.4816, Test Acc=0.8344
# Epoch 337: Train Loss=0.0130, Train Acc=1.0000, Test Loss=0.4691, Test Acc=0.8405
# Epoch 338: Train Loss=0.0116, Train Acc=1.0000, Test Loss=0.4489, Test Acc=0.8773
# Epoch 339: Train Loss=0.0128, Train Acc=1.0000, Test Loss=0.4530, Test Acc=0.8896
# Epoch 340: Train Loss=0.0151, Train Acc=1.0000, Test Loss=0.4571, Test Acc=0.8466
# Epoch 341: Train Loss=0.0127, Train Acc=1.0000, Test Loss=0.4960, Test Acc=0.8282
# Epoch 342: Train Loss=0.0127, Train Acc=1.0000, Test Loss=0.4800, Test Acc=0.8282
# Epoch 343: Train Loss=0.0130, Train Acc=1.0000, Test Loss=0.4629, Test Acc=0.8466
# Epoch 344: Train Loss=0.0117, Train Acc=1.0000, Test Loss=0.4543, Test Acc=0.8466
# Epoch 345: Train Loss=0.0106, Train Acc=1.0000, Test Loss=0.4680, Test Acc=0.8528
# Epoch 346: Train Loss=0.0110, Train Acc=1.0000, Test Loss=0.4771, Test Acc=0.8466
# Epoch 347: Train Loss=0.0104, Train Acc=1.0000, Test Loss=0.4970, Test Acc=0.8344
# Epoch 348: Train Loss=0.0137, Train Acc=0.9985, Test Loss=0.4443, Test Acc=0.8896
# Epoch 349: Train Loss=0.0129, Train Acc=1.0000, Test Loss=0.4057, Test Acc=0.9264
# Epoch 350: Train Loss=0.0152, Train Acc=0.9985, Test Loss=0.4455, Test Acc=0.8466
#
# 💾 Best model saved at epoch 203 with test loss 0.3982
# 📂 Model saved to: C:\Users\nidhi\Nidhi Programs\NEW MODELS\Hard SPLIT\ONE - HOT\No WEIGHT DECAY + Drop out\Batch size 64\A+B+C_64OneHOT_203.pt
#
# 📌 Classification Metrics at Best Test Loss Epoch:
# ✅ Accuracy:    0.9080
# ✅ Precision:   0.9182
# ✅ Recall:      0.9439
# ✅ F1 Score:    0.9309
# ✅ Specificity: 0.8393
#
# 📊 Confusion Matrix:
# [[ 47   9]
#  [  6 101]]
# 🖼️ Confusion matrix plot saved to: C:\Users\nidhi\Nidhi Programs\NEW MODELS\Hard SPLIT\ONE - HOT\No WEIGHT DECAY + Drop out\Batch size 64\Confusion_Matrix_A+B+C_203.png
